# %%
import os
import uuid

def is_uuid_name(name: str) -> bool:
    """Return True if the string is a valid UUID."""
    try:
        uuid.UUID(name)
        return True
    except ValueError:
        return False


def rename_midis_to_uuid():
    base_dir = os.getcwd()
    midi_dir = os.path.join(base_dir, "MIDI")

    if not os.path.isdir(midi_dir):
        print(f'Error: "MIDI" folder not found at {midi_dir}')
        return

    renamed_count = 0
    skipped_count = 0

    for filename in os.listdir(midi_dir):
        lower = filename.lower()

        if lower.endswith(".mid") or lower.endswith(".midi"):
            old_path = os.path.join(midi_dir, filename)

            name_without_ext, ext = os.path.splitext(filename)

            # ⭐ Skip if already UUID
            if is_uuid_name(name_without_ext):
                #print(f"Skipping (already UUID): {filename}")
                skipped_count += 1
                continue

            new_name = f"{uuid.uuid4()}{ext}"
            new_path = os.path.join(midi_dir, new_name)

            os.rename(old_path, new_path)

            print(f"{filename}  ->  {new_name}")
            renamed_count += 1

    print(f"\nDone. Renamed {renamed_count} MIDI files. Skipped {skipped_count}.")

rename_midis_to_uuid()
# Out:
# MIDI Audio 257.mid  ->  38d25858-c2a4-42e0-864a-ffaff6625d62.mid
# MIDI Audio 243.mid  ->  f67dbaec-b1d7-4270-9f64-55c99c4c9d8d.mid
# MIDI Audio 294.mid  ->  1cc014da-9f73-44dc-97e6-88b44156c880.mid
# MIDI Audio 280.mid  ->  56f71ced-da3e-4e3b-aeb6-960d45493dad.mid
# MIDI Audio 281.mid  ->  51f2fc43-19c3-4f7a-a875-8facb13b136c.mid
# MIDI Audio 295.mid  ->  87354bc9-b824-48b3-9fe6-088527441788.mid
# MIDI Audio 242.mid  ->  5753a73a-f4cf-478b-a6d0-d1ed54da752c.mid
# MIDI Audio 308.mid  ->  8f4e4b7d-6c29-4d97-8f50-5dcc3f99b88b.mid
# MIDI Audio 240.mid  ->  568a1b37-c5cf-48ea-b572-66b1d82ff033.mid
# MIDI Audio 254.mid  ->  0a8186d1-f1a5-446c-a8ca-045b0f72f049.mid
# MIDI Audio 268.mid  ->  e9dc7666-6828-4937-8b44-6e6c11eaa23e.mid
# MIDI Audio 283.mid  ->  7b6161f1-44c2-4b55-a9bd-e9e1ce9cb1eb.mid
# MIDI Audio 297.mid  ->  0b84586d-8964-4d95-9420-5b9dad0aaaa7.mid
# MIDI Audio 296.mid  ->  75278030-2baf-484f-90ce-0eb36d13323b.mid
# MIDI Audio 282.mid  ->  f63dc71a-f2b6-45aa-afcd-b7d007975d7f.mid
# MIDI Audio 269.mid  ->  0a4a3f2a-d059-4735-b652-39aa6726cfc4.mid
# MIDI Audio 255.mid  ->  6c4aaf49-2451-4083-b560-01f42ab61a2c.mid
# MIDI Audio 241.mid  ->  66cc38c3-59ce-479d-a540-b6eb1f93df2f.mid
# MIDI Audio 309.mid  ->  1fb12bca-ab2b-45f8-a950-7fbaa7b9c925.mid
# MIDI Audio 279.mid  ->  d917ca0a-9360-4fd5-9cfa-28f029c48930.mid
# MIDI Audio 245.mid  ->  305f3f10-601b-4cc2-a803-2e74cbd72eec.mid
# MIDI Audio 251.mid  ->  3d92d6a7-7d4e-4336-a3f3-5184d5263696.mid
# MIDI Audio 286.mid  ->  e1ba17fe-8cf8-4f86-9b64-eb1729ff98e2.mid
# MIDI Audio 292.mid  ->  b86e3edc-6b38-43fa-8d42-d56fd6225960.mid
# MIDI Audio 293.mid  ->  a86e8d1b-88ac-448f-b4aa-76ecff88277a.mid
# MIDI Audio 287.mid  ->  4f992c1f-e61c-4631-831e-02d9ba6e6b73.mid
# MIDI Audio 250.mid  ->  192e0b7b-a062-4f9b-9523-f30e8ef5e8fe.mid
# MIDI Audio 244.mid  ->  84e8fc6a-a1d1-493f-9a1a-3a49d026be43.mid
# MIDI Audio 278.mid  ->  86cf4976-7671-4a49-9a87-727704d4b68f.mid
# MIDI Audio 252.mid  ->  38f24eb0-55b5-44b1-b4d8-57c2446cf381.mid
# MIDI Audio 246.mid  ->  972bf1ff-d6a6-47de-b93c-18e5ca9056a9.mid
# MIDI Audio 291.mid  ->  7e80f6ef-3a1d-42d1-9e10-aef7bf600a2a.mid
# MIDI Audio 285.mid  ->  1bd618d1-3e9c-460a-94e4-0ea775a6e44b.mid
# MIDI Audio 284.mid  ->  b26c6621-063e-46b7-8fb6-547c9161c4ce.mid
# MIDI Audio 290.mid  ->  7faaca0a-b334-4cb1-ba23-684cde7f0df4.mid
# MIDI Audio 253.mid  ->  c3ea45a6-9ccd-48b7-a0a3-c57f43a7af9c.mid
# MIDI Audio 234.mid  ->  9c9815a7-8089-40fe-becc-2167198cc994.mid
# MIDI Audio 235.mid  ->  47591110-e592-4db1-b850-09660cac4bd2.mid
# MIDI Audio 237.mid  ->  6ab6330c-0274-4749-8f95-0edc7dc54eb9.mid
# MIDI Audio 236.mid  ->  53ff1f91-d660-4820-9ed5-9fdb80c10486.mid
# MIDI Audio 232.mid  ->  3ab5de87-bf0d-4fb8-a658-00f55ce39a12.mid
# MIDI Audio 233.mid  ->  c92c2df5-9694-4acd-abba-23b1c5c01669.mid
# MIDI Audio 231.mid  ->  cc457313-a64c-4eb6-88e5-0472975cb38e.mid
# MIDI Audio 230.mid  ->  58e8bf4c-1a87-4cf8-b858-7ba696f8bdc6.mid
# MIDI Audio 238.mid  ->  90b17f11-d8ac-40db-a381-ddf367dabaee.mid
# MIDI Audio 239.mid  ->  48dce475-eee6-440a-8d60-302a255e836d.mid
# MIDI Audio 302.mid  ->  0643ee14-344c-4dd6-91bb-eda3e77e58b7.mid
# MIDI Audio 276.mid  ->  653f06bc-50ba-4ed1-9eef-2f2a048028a2.mid
# MIDI Audio 262.mid  ->  8ee115ee-f367-4eda-9adf-4310583f0f50.mid
# MIDI Audio 289.mid  ->  2f2977a4-9071-4bec-b01a-b9bd82eb34b4.mid
# MIDI Audio 288.mid  ->  198f3068-2133-49d5-85bf-9cebd07831b3.mid
# MIDI Audio 263.mid  ->  7d9ca9d5-4213-462b-bd8c-4f25519b0c29.mid
# MIDI Audio 277.mid  ->  9c74667d-f416-4450-a75c-8ec9434f6655.mid
# MIDI Audio 303.mid  ->  5b9c2416-92db-41a4-8754-1aa36bc4e82f.mid
# MIDI Audio 301.mid  ->  eae087a7-63ea-457b-8d50-96eab2b15205.mid
# MIDI Audio 261.mid  ->  ab716b5e-c9ed-429f-8b57-b07ccb8de10f.mid
# MIDI Audio 275.mid  ->  cf10344f-4981-4b79-a550-c936ec0a54fd.mid
# MIDI Audio 248.mid  ->  72124c42-8b45-4a7d-b2cf-a1e204c0fa35.mid
# MIDI Audio 274.mid  ->  049af841-e809-4233-af54-961401b52bca.mid
# MIDI Audio 300.mid  ->  de22df99-5092-4ea8-bd2e-ba724cb411c2.mid
# MIDI Audio 310.mid  ->  64440cc8-fa8a-4450-9d1e-6de03814d057.mid
# MIDI Audio 304.mid  ->  dc71ac43-ae88-4dd1-97d3-aa8e56378da7.mid
# MIDI Audio 264.mid  ->  108c4f9f-4b76-48f0-84e8-300d9e256075.mid
# MIDI Audio 270.mid  ->  2559d371-2d42-482e-a0c0-98d9a3fe4461.mid
# MIDI Audio 271.mid  ->  29c9cbf7-0213-4e64-a0a2-2840a8e131d0.mid
# MIDI Audio 265.mid  ->  dcebfec1-0868-4350-a912-e0ad98ba23ab.mid
# MIDI Audio 305.mid  ->  363e3184-edbe-4dd1-8628-f17daacf48aa.mid
# MIDI Audio 311.mid  ->  0d91a8a2-4e26-46c0-82a1-154462473899.mid
# MIDI Audio 307.mid  ->  4bf674f8-67f7-41e8-86db-ec0fe520da5f.mid
# MIDI Audio 273.mid  ->  7fd50e52-1e6a-45a5-905e-f31493580e91.mid
# MIDI Audio 267.mid  ->  2d47f639-df4f-41a5-afc6-6fdf47c1c184.mid
# MIDI Audio 298.mid  ->  c07e9bea-e92f-462c-ba46-bd7c76c54cde.mid
# MIDI Audio 299.mid  ->  4c3787c4-d817-40a7-b2e3-e92b3f464daa.mid
# MIDI Audio 266.mid  ->  671dc02c-a7fb-4ca8-86fe-16cee9932a61.mid
# MIDI Audio 272.mid  ->  300ef216-aa52-4cce-a43f-d565c110c2e8.mid
# MIDI Audio 312.mid  ->  e20443fa-0886-4db3-be9d-8a7bdabc8cc9.mid
# MIDI Audio 306.mid  ->  5634370e-b977-42e5-a720-c1ba7b116dd8.mid
#
# Done. Renamed 77 MIDI files. Skipped 347.
