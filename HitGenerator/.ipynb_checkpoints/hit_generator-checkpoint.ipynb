# %%
# hit_generator.py
# Single-voice drum step generator (16th-note grid) with continuous velocity
# IMPORTANT: training data is loaded as (file, pitch) records via MultiVoiceMidiDataset
# so each sample is ONE pitch lane, not a whole multi-pitch MIDI file.

from __future__ import annotations

import subprocess
import signal
import sys
import os
import random
from dataclasses import dataclass
from datetime import datetime
from typing import Dict, Tuple, Optional, List

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

from mid_to_velocity import MidiGridConfig, MultiVoiceMidiDataset
from midi_export import export_single_voice_steps_to_midi, MidiExportConfig


# ----------------------------
# Utils
# ----------------------------

def set_seed(seed: int = 42) -> None:
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def circular_pad_1d(x: torch.Tensor, pad: int) -> torch.Tensor:
    """
    Circular padding for 1D conv.
    x: (B, C, T)
    """
    if pad <= 0:
        return x
    return torch.cat([x[..., -pad:], x, x[..., :pad]], dim=-1)


def masked_huber(pred: torch.Tensor, target: torch.Tensor, mask: torch.Tensor, delta: float = 0.1) -> torch.Tensor:
    """
    pred/target: (B, T)
    mask: (B, T) in {0,1} or [0,1]
    """
    loss = F.smooth_l1_loss(pred, target, reduction="none", beta=delta)  # (B, T)
    denom = mask.sum().clamp_min(1.0)
    return (loss * mask).sum() / denom


def _ensure_pt_name(name: str) -> str:
    return name if name.endswith(".pt") else (name + ".pt")


def make_unique_model_name(prefix: str = "single_voice_tcn") -> str:
    # Example: single_voice_tcn_20260226_153012_482931
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    suffix = f"{random.randint(0, 999999):06d}"
    return f"{prefix}_{ts}_{suffix}"


# ----------------------------
# Model: TCN with circular padding
# ----------------------------

class CircularConv1d(nn.Module):
    def __init__(self, in_ch: int, out_ch: int, kernel_size: int, dilation: int):
        super().__init__()
        assert kernel_size % 2 == 1, "Use odd kernel size for 'same' length."
        self.kernel_size = kernel_size
        self.dilation = dilation
        self.conv = nn.Conv1d(
            in_channels=in_ch,
            out_channels=out_ch,
            kernel_size=kernel_size,
            dilation=dilation,
            padding=0,  # manual circular padding
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        pad = self.dilation * (self.kernel_size - 1) // 2
        x = circular_pad_1d(x, pad)
        return self.conv(x)


class TCNBlock(nn.Module):
    def __init__(self, channels: int, kernel_size: int, dilation: int, dropout: float = 0.1):
        super().__init__()
        self.conv1 = CircularConv1d(channels, channels, kernel_size=kernel_size, dilation=dilation)
        self.conv2 = CircularConv1d(channels, channels, kernel_size=kernel_size, dilation=dilation)
        self.dropout = nn.Dropout(dropout)
        self.norm1 = nn.GroupNorm(num_groups=8 if channels >= 8 else 1, num_channels=channels)
        self.norm2 = nn.GroupNorm(num_groups=8 if channels >= 8 else 1, num_channels=channels)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        residual = x

        x = self.conv1(x)
        x = self.norm1(x)
        x = F.gelu(x)
        x = self.dropout(x)

        x = self.conv2(x)
        x = self.norm2(x)
        x = F.gelu(x)
        x = self.dropout(x)

        return x + residual


class SingleVoiceTCN(nn.Module):
    """
    Input per step:
      - hit_in (0/1, possibly corrupted)
      - vel_in (0..1, possibly corrupted)
      - mask_in (1 if masked/unknown, 0 if known)
    x: (B, 3, T)

    Output (SINGLE PITCH GRID):
      - hit_logits: (B, T)
      - vel_mu: (B, T) in [0,1]
      - vel_log_sigma: (B, T) optional
    """

    def __init__(
        self,
        in_channels: int = 3,
        hidden: int = 128,
        kernel_size: int = 3,
        dilations: Tuple[int, ...] = (1, 2, 4, 8, 16, 1, 2, 4),
        dropout: float = 0.1,
        predict_sigma: bool = True,
    ):
        super().__init__()
        self.predict_sigma = predict_sigma

        self.in_proj = nn.Conv1d(in_channels, hidden, kernel_size=1)
        self.blocks = nn.ModuleList([TCNBlock(hidden, kernel_size=kernel_size, dilation=d, dropout=dropout) for d in dilations])

        self.hit_head = nn.Conv1d(hidden, 1, kernel_size=1)  # logits
        self.vel_head = nn.Conv1d(hidden, 1, kernel_size=1)  # mu -> sigmoid

        self.sigma_head = nn.Conv1d(hidden, 1, kernel_size=1) if predict_sigma else None

    def forward(self, x: torch.Tensor) -> Dict[str, torch.Tensor]:
        h = self.in_proj(x)
        for blk in self.blocks:
            h = blk(h)

        hit_logits = self.hit_head(h).squeeze(1)                 # (B, T)
        vel_mu = torch.sigmoid(self.vel_head(h).squeeze(1))      # (B, T)

        out = {"hit_logits": hit_logits, "vel_mu": vel_mu}
        if self.predict_sigma and self.sigma_head is not None:
            out["vel_log_sigma"] = self.sigma_head(h).squeeze(1) # (B, T)

        return out


# ----------------------------
# Masking / corruption for denoising
# ----------------------------

@dataclass
class MaskConfig:
    p_mask: float = 0.5
    p_flip_hit: float = 0.0
    p_jitter_vel: float = 0.0


def corrupt_inputs(
    hit: torch.Tensor,  # (B,T)
    vel: torch.Tensor,  # (B,T)
    cfg: MaskConfig,
) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
    """
    Returns: hit_in, vel_in, mask (1 where masked)
    """
    B, T = hit.shape
    device = hit.device

    mask = (torch.rand((B, T), device=device) < cfg.p_mask).float()

    hit_in = hit.clone()
    vel_in = vel.clone()

    # masked steps -> 0, model uses mask channel to know it's unknown
    hit_in = hit_in * (1.0 - mask)
    vel_in = vel_in * (1.0 - mask)

    # optional corruption on known steps
    if cfg.p_flip_hit > 0.0:
        flip = ((torch.rand((B, T), device=device) < cfg.p_flip_hit).float()) * (1.0 - mask)
        hit_in = torch.where(flip > 0.0, 1.0 - hit_in, hit_in)

    if cfg.p_jitter_vel > 0.0:
        noise = torch.randn((B, T), device=device) * cfg.p_jitter_vel
        vel_in = torch.clamp(vel_in + noise * (1.0 - mask), 0.0, 1.0)

    return hit_in, vel_in, mask


# ----------------------------
# DATA LOADING (FIXED): per-pitch samples, not per-file
# ----------------------------

def load_training_tensors(
    midi_dir: str,
    cfg: MidiGridConfig,
    *,
    batch_size: int = 256,
    min_hits_per_voice: int = 1,
    max_hits_per_voice: Optional[int] = None,
) -> Tuple[torch.Tensor, torch.Tensor]:
    """
    Returns:
      data_hit: (N, T)
      data_vel: (N, T)

    N counts *pitches*, not files:
    MultiVoiceMidiDataset indexes (file, pitch) pairs and each item returns
    one pitch-lane grid. (This is the core fix.)
    """
    ds = MultiVoiceMidiDataset(
        midi_dir,
        cfg,
        min_hits_per_voice=min_hits_per_voice,
        max_hits_per_voice=max_hits_per_voice,
        include_pitch=False,  # pitch not needed for training
    )

    dl = DataLoader(ds, batch_size=batch_size, shuffle=True, drop_last=False)

    all_hit: List[torch.Tensor] = []
    all_vel: List[torch.Tensor] = []

    for batch in dl:
        # batch["hit"], batch["vel"] : (B, T)
        all_hit.append(batch["hit"])
        all_vel.append(batch["vel"])

    data_hit = torch.cat(all_hit, dim=0).float()
    data_vel = torch.cat(all_vel, dim=0).float()

    return data_hit, data_vel


# ----------------------------
# Saving / Loading
# ----------------------------

def save_model(
    model: nn.Module,
    path: str,
    *,
    model_config: Optional[dict] = None,
    best_loss: Optional[float] = None,
    best_f1: Optional[float] = None,
) -> None:
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    torch.save(
        {
            "model_state_dict": model.state_dict(),
            "model_config": model_config,
            "best_loss": best_loss,
            "best_f1": best_f1,
        },
        path,
    )


def load_checkpoint(path: str, device: str = "mps") -> dict:
    if not os.path.exists(path):
        raise FileNotFoundError(f"Checkpoint not found: {path}")
    return torch.load(path, map_location=torch.device(device), weights_only = False)

# ----------------------------
# Split the data into training / testing
# ----------------------------

def split_tensors(
    data_hit: torch.Tensor,
    data_vel: torch.Tensor,
    train_frac: float = 0.8,
    val_frac: float = 0.1,
    seed: int = 42,
) -> tuple[tuple[torch.Tensor, torch.Tensor], tuple[torch.Tensor, torch.Tensor], tuple[torch.Tensor, torch.Tensor]]:
    assert 0 < train_frac < 1 and 0 <= val_frac < 1 and train_frac + val_frac < 1
    N = data_hit.shape[0]
    g = torch.Generator()
    g.manual_seed(seed)
    idx = torch.randperm(N, generator=g)  # CPU

    n_train = int(N * train_frac)
    n_val = int(N * val_frac)
    train_idx = idx[:n_train]
    val_idx = idx[n_train:n_train + n_val]
    test_idx = idx[n_train + n_val:]

    return (
        (data_hit[train_idx], data_vel[train_idx]),
        (data_hit[val_idx], data_vel[val_idx]),
        (data_hit[test_idx], data_vel[test_idx]),
    )

# ----------------------------
# Evaluate model for accuracy
# ----------------------------

@torch.no_grad()
def evaluate_denoise(
    model: nn.Module,
    data_hit: torch.Tensor,
    data_vel: torch.Tensor,
    *,
    batch_size: int,
    device: str,
    mask_cfg: MaskConfig,
    lambda_vel: float,
) -> tuple[float, float, float, float]:
    """
    Returns: (avg_loss, hit_accuracy_on_masked_steps)
    """
    device_t = torch.device(device)
    model.eval()

    N, T = data_hit.shape
    total_loss = 0.0
    total_seen = 0

    TP = FP = FN = TN = 0.0

    for i in range(0, N, batch_size):
        hit = data_hit[i:i+batch_size].to(device_t)
        vel = data_vel[i:i+batch_size].to(device_t)

        hit_in, vel_in, mask = corrupt_inputs(hit, vel, mask_cfg)
        x = torch.stack([hit_in, vel_in, mask], dim=1)  # (B,3,T)
        out = model(x)

        # same loss as training (masked-only)
        hit_loss = F.binary_cross_entropy_with_logits(out["hit_logits"], hit, reduction="none")
        hit_loss = (hit_loss * mask).sum() / mask.sum().clamp_min(1.0)

        vel_mask = mask * hit
        vel_loss = masked_huber(out["vel_mu"], vel, vel_mask, delta=0.1)

        loss = hit_loss + lambda_vel * vel_loss

        bs = hit.shape[0]
        total_loss += float(loss.item()) * bs
        total_seen += bs

        # hit accuracy on masked steps
        pred = (torch.sigmoid(out["hit_logits"]) > 0.5).float()

        # Only evaluate on masked steps
        m = mask > 0.0
        y = hit.float()

        tp = ((pred == 1) & (y == 1) & m).sum().item()
        fp = ((pred == 1) & (y == 0) & m).sum().item()
        fn = ((pred == 0) & (y == 1) & m).sum().item()
        tn = ((pred == 0) & (y == 0) & m).sum().item()

        TP += tp; FP += fp; FN += fn; TN += tn

    avg_loss = total_loss / max(1, total_seen)
    precision = TP / max(1e-9, (TP + FP))
    recall    = TP / max(1e-9, (TP + FN))
    f1        = 2 * precision * recall / max(1e-9, (precision + recall))
    return avg_loss, precision, recall, f1
    
# ----------------------------
# Training
# ----------------------------

def train(
    model: nn.Module,
    data_hit: torch.Tensor,   # (N, T)
    data_vel: torch.Tensor,   # (N, T)
    *,
    val_hit: Optional[torch.Tensor] = None,
    val_vel: Optional[torch.Tensor] = None,
    test_hit: Optional[torch.Tensor] = None,
    test_vel: Optional[torch.Tensor] = None,
    epochs: Optional[int] = 20,
    batch_size: int = 128,
    lr: float = 2e-3,
    device: str = "mps",
    mask_cfg: MaskConfig = MaskConfig(p_mask=0.5),
    lambda_vel: float = 1.0,
    save_best_path: Optional[str] = None,
    model_config: Optional[dict] = None,
    best_init: float = -1.0,   # best F1 so far
) -> float:
    device_t = torch.device(device)
    model.to(device_t)

    opt = torch.optim.AdamW(model.parameters(), lr=lr)
    best_f1 = float(best_init)

    N, T = data_hit.shape

    # simple minibatching from tensors
    def batches():
        idx = torch.randperm(N)  # CPU
        for i in range(0, N, batch_size):
            j = idx[i:i+batch_size]
            hit = data_hit[j].to(device_t)
            vel = data_vel[j].to(device_t)
            yield hit, vel

    epoch = 0
    while True:
        if epochs is not None and epoch >= epochs:
            break

        model.train()
        running = 0.0
        n_seen = 0

        for hit, vel in batches():
            hit_in, vel_in, mask = corrupt_inputs(hit, vel, mask_cfg)

            x = torch.stack([hit_in, vel_in, mask], dim=1)  # (B, 3, T)
            out = model(x)

            # hit loss on masked steps only
            hit_loss = F.binary_cross_entropy_with_logits(out["hit_logits"], hit, reduction="none")
            hit_loss = (hit_loss * mask).sum() / mask.sum().clamp_min(1.0)

            # velocity loss only on masked steps (and only where there is a hit)
            vel_mask = mask * hit  # only care vel where a hit exists
            vel_loss = masked_huber(out["vel_mu"], vel, vel_mask, delta=0.1)

            loss = hit_loss + lambda_vel * vel_loss

            opt.zero_grad(set_to_none=True)
            loss.backward()
            opt.step()

            running += float(loss.item()) * hit.shape[0]
            n_seen += hit.shape[0]

        epoch_loss = running / max(1, n_seen)
        print(f"epoch {epoch}  loss={epoch_loss:.6f}")

        # ---- VALIDATION (used for checkpointing) ----
        if val_hit is not None and val_vel is not None:
            val_loss, precision, recall, val_f1 = evaluate_denoise(
                model,
                val_hit,
                val_vel,
                batch_size=batch_size,
                device=device,
                mask_cfg=mask_cfg,
                lambda_vel=lambda_vel,
            )
        
            print(f"          val_loss={val_loss:.6f}  Precision={precision:.3f} Recall={recall:.3f} F1={val_f1:.3f}")
        
            if save_best_path is not None and val_f1 > best_f1:
                best_f1 = val_f1
                save_model(
                    model,
                    path=save_best_path,
                    model_config=model_config,
                    best_loss=val_loss,
                    best_f1=best_f1,
                )
                print(f"  saved best -> {save_best_path} (best_val_f1={best_f1:.3f})")
        
        # ---- TEST (report only) ----
        if test_hit is not None and test_vel is not None and (epoch % 10 == 0):
            test_loss, tprec, trec, test_f1 = evaluate_denoise(
                model,
                test_hit,
                test_vel,
                batch_size=batch_size,
                device=device,
                mask_cfg=mask_cfg,
                lambda_vel=lambda_vel,
            )
            print(f"          TEST -> loss={test_loss:.6f}  Precision={tprec:.3f} Recall={trec:.3f} F1={test_f1:.3f}")
    
        epoch += 1

    return best_f1


# ----------------------------
# Example main
# ----------------------------

if __name__ == "__main__":
    set_seed(42)

    cfg = MidiGridConfig(
        bars=8,
        steps_per_bar=16,
        drum_channel=None,
        voice_pitch=None,          # ignored by MultiVoiceMidiDataset indexing
        step_merge="max",
        quantize="nearest",
        align_first_hit_to_zero=False,
    )

    device = "mps" if torch.backends.mps.is_available() else "cpu"
    print("device:", device)
    
    data_hit, data_vel = load_training_tensors(
        midi_dir="MIDI",
        cfg=cfg,
        batch_size=256,
        min_hits_per_voice=4,
        max_hits_per_voice=64,
    )
    N, T = data_hit.shape
    print("Loaded per-pitch samples:", (N, T))

    (train_hit, train_vel), (val_hit, val_vel), (test_hit, test_vel) = split_tensors(
        data_hit, data_vel, train_frac=0.8, val_frac=0.1, seed=42
    )
    print(f"Split: train={train_hit.shape[0]}  val={val_hit.shape[0]}  test={test_hit.shape[0]}")

    
    # Pass a filename (e.g. "candidate.pt" or "candidate") to resume.
    # Pass None to start a new run with a unique filename.
    resume_name: Optional[str] = None  # e.g. "single_voice_tcn_20260226_153012_482931" or "candidate.pt"

    default_model_cfg = {
        "in_channels": 3,
        "hidden": 128,
        "kernel_size": 3,
        "dilations": (1, 2, 4, 8, 16, 1, 2, 4),
        "dropout": 0.15,
        "predict_sigma": True,
    }

    best_init: float = -1.0

    if resume_name is not None:
        ckpt_path = os.path.join("Models", _ensure_pt_name(resume_name))
        ckpt = load_checkpoint(ckpt_path, device=device)
        model_cfg = ckpt.get("model_config") or default_model_cfg
        model = SingleVoiceTCN(**model_cfg)
        model.load_state_dict(ckpt["model_state_dict"])
        best_init = float(ckpt.get("best_f1", -1.0))
        model_name = os.path.splitext(os.path.basename(ckpt_path))[0]
        best_path = ckpt_path
        print(f"Resuming from: {best_path} (prev_best_f1={best_init if best_init >= 0.0 else 'unknown'})")
    else:
        model_cfg = default_model_cfg
        model = SingleVoiceTCN(**model_cfg)
        model_name = make_unique_model_name(prefix="single_voice_tcn")
        best_path = os.path.join("Models", _ensure_pt_name(model_name))
        print(f"Starting new run: {best_path}")

    caff = None
    
    try:
        caff = subprocess.Popen(["caffeinate", "-dimsu"])
    
        train(
            model=model,
            data_hit=train_hit,
            data_vel=train_vel,
            val_hit=val_hit,
            val_vel=val_vel,
            test_hit=test_hit,
            test_vel=test_vel,
            epochs=None,
            batch_size=128,
            lr=2e-3,
            device=device,
            mask_cfg=MaskConfig(p_mask=0.55),
            lambda_vel=1.5,
            save_best_path=best_path,
            model_config=model_cfg,
            best_init=best_init,
        )
        
    except KeyboardInterrupt:
        print("\nStopped by user. Done.")
    finally:
        if caff is not None:
            caff.terminate()
            caff.wait()
# Out:
# Loaded per-pitch samples: (730, 128)
# Split: train=584  val=73  test=73
# Starting new run: Models/single_voice_tcn_20260301_181247_670487.pt
# epoch 0  loss=1.619119
#           val_loss=1.032625  Precision=0.341 Recall=0.875 F1=0.491
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.491)
#           TEST -> loss=1.025543  Precision=0.320 Recall=0.866 F1=0.468
# epoch 1  loss=0.844060
#           val_loss=0.711743  Precision=1.000 Recall=0.002 F1=0.003
# epoch 2  loss=0.709121
#           val_loss=0.603384  Precision=0.811 Recall=0.567 F1=0.667
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.667)
# epoch 3  loss=0.618670
#           val_loss=0.532843  Precision=0.879 Recall=0.597 F1=0.711
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.711)
# epoch 4  loss=0.554533
#           val_loss=0.477050  Precision=0.827 Recall=0.767 F1=0.796
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.796)
# epoch 5  loss=0.511495
#           val_loss=0.435455  Precision=0.903 Recall=0.703 F1=0.791
# epoch 6  loss=0.483345
#           val_loss=0.423251  Precision=0.885 Recall=0.811 F1=0.846
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.846)
# epoch 7  loss=0.469441
#           val_loss=0.419999  Precision=0.915 Recall=0.768 F1=0.835
# epoch 8  loss=0.454872
#           val_loss=0.394449  Precision=0.892 Recall=0.831 F1=0.860
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.860)
# epoch 9  loss=0.447805
#           val_loss=0.375751  Precision=0.921 Recall=0.799 F1=0.856
# epoch 10  loss=0.442122
#           val_loss=0.382102  Precision=0.894 Recall=0.850 F1=0.871
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.871)
#           TEST -> loss=0.392864  Precision=0.884 Recall=0.841 F1=0.862
# epoch 11  loss=0.431068
#           val_loss=0.371478  Precision=0.892 Recall=0.828 F1=0.859
# epoch 12  loss=0.421590
#           val_loss=0.394796  Precision=0.921 Recall=0.807 F1=0.860
# epoch 13  loss=0.418935
#           val_loss=0.360416  Precision=0.873 Recall=0.875 F1=0.874
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.874)
# epoch 14  loss=0.409967
#           val_loss=0.344580  Precision=0.934 Recall=0.766 F1=0.842
# epoch 15  loss=0.405821
#           val_loss=0.336663  Precision=0.907 Recall=0.814 F1=0.858
# epoch 16  loss=0.397766
#           val_loss=0.329126  Precision=0.894 Recall=0.868 F1=0.881
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.881)
# epoch 17  loss=0.381658
#           val_loss=0.364344  Precision=0.915 Recall=0.809 F1=0.858
# epoch 18  loss=0.364877
#           val_loss=0.325227  Precision=0.896 Recall=0.867 F1=0.881
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.881)
# epoch 19  loss=0.372396
#           val_loss=0.295444  Precision=0.918 Recall=0.844 F1=0.879
# epoch 20  loss=0.363645
#           val_loss=0.297312  Precision=0.906 Recall=0.849 F1=0.877
#           TEST -> loss=0.325178  Precision=0.887 Recall=0.832 F1=0.859
# epoch 21  loss=0.349004
#           val_loss=0.291244  Precision=0.892 Recall=0.861 F1=0.876
# epoch 22  loss=0.341398
#           val_loss=0.315345  Precision=0.879 Recall=0.821 F1=0.849
# epoch 23  loss=0.343091
#           val_loss=0.294774  Precision=0.890 Recall=0.851 F1=0.870
# epoch 24  loss=0.336742
#           val_loss=0.304222  Precision=0.893 Recall=0.824 F1=0.857
# epoch 25  loss=0.339246
#           val_loss=0.280015  Precision=0.920 Recall=0.865 F1=0.891
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.891)
# epoch 26  loss=0.340566
#           val_loss=0.282211  Precision=0.906 Recall=0.868 F1=0.887
# epoch 27  loss=0.334764
#           val_loss=0.273146  Precision=0.907 Recall=0.857 F1=0.882
# epoch 28  loss=0.328470
#           val_loss=0.280780  Precision=0.910 Recall=0.852 F1=0.880
# epoch 29  loss=0.327357
#           val_loss=0.291771  Precision=0.905 Recall=0.850 F1=0.877
# epoch 30  loss=0.326461
#           val_loss=0.266442  Precision=0.899 Recall=0.872 F1=0.886
#           TEST -> loss=0.304852  Precision=0.876 Recall=0.855 F1=0.865
# epoch 31  loss=0.327579
#           val_loss=0.295731  Precision=0.908 Recall=0.875 F1=0.891
# epoch 32  loss=0.327650
#           val_loss=0.281213  Precision=0.894 Recall=0.836 F1=0.864
# epoch 33  loss=0.319988
#           val_loss=0.264938  Precision=0.916 Recall=0.855 F1=0.885
# epoch 34  loss=0.319932
#           val_loss=0.266986  Precision=0.910 Recall=0.867 F1=0.888
# epoch 35  loss=0.313883
#           val_loss=0.292783  Precision=0.901 Recall=0.832 F1=0.865
# epoch 36  loss=0.314904
#           val_loss=0.253679  Precision=0.905 Recall=0.898 F1=0.901
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.901)
# epoch 37  loss=0.320594
#           val_loss=0.273977  Precision=0.901 Recall=0.845 F1=0.872
# epoch 38  loss=0.314207
#           val_loss=0.276432  Precision=0.912 Recall=0.850 F1=0.880
# epoch 39  loss=0.316280
#           val_loss=0.271870  Precision=0.883 Recall=0.870 F1=0.877
# epoch 40  loss=0.314288
#           val_loss=0.263838  Precision=0.915 Recall=0.861 F1=0.887
#           TEST -> loss=0.285583  Precision=0.889 Recall=0.874 F1=0.881
# epoch 41  loss=0.319889
#           val_loss=0.283291  Precision=0.932 Recall=0.822 F1=0.874
# epoch 42  loss=0.317187
#           val_loss=0.289294  Precision=0.902 Recall=0.852 F1=0.876
# epoch 43  loss=0.317564
#           val_loss=0.267984  Precision=0.909 Recall=0.879 F1=0.894
# epoch 44  loss=0.308902
#           val_loss=0.265951  Precision=0.924 Recall=0.836 F1=0.878
# epoch 45  loss=0.305344
#           val_loss=0.259711  Precision=0.891 Recall=0.883 F1=0.887
# epoch 46  loss=0.308054
#           val_loss=0.267703  Precision=0.908 Recall=0.879 F1=0.893
# epoch 47  loss=0.303143
#           val_loss=0.253630  Precision=0.909 Recall=0.870 F1=0.889
# epoch 48  loss=0.310909
#           val_loss=0.254631  Precision=0.892 Recall=0.890 F1=0.891
# epoch 49  loss=0.307588
#           val_loss=0.264798  Precision=0.899 Recall=0.874 F1=0.886
# epoch 50  loss=0.302720
#           val_loss=0.258839  Precision=0.913 Recall=0.864 F1=0.888
#           TEST -> loss=0.287697  Precision=0.927 Recall=0.833 F1=0.878
# epoch 51  loss=0.303070
#           val_loss=0.254541  Precision=0.915 Recall=0.871 F1=0.893
# epoch 52  loss=0.307574
#           val_loss=0.267679  Precision=0.874 Recall=0.881 F1=0.877
# epoch 53  loss=0.307244
#           val_loss=0.266088  Precision=0.918 Recall=0.843 F1=0.879
# epoch 54  loss=0.299343
#           val_loss=0.274034  Precision=0.910 Recall=0.850 F1=0.879
# epoch 55  loss=0.297774
#           val_loss=0.284114  Precision=0.889 Recall=0.865 F1=0.877
# epoch 56  loss=0.304896
#           val_loss=0.265853  Precision=0.922 Recall=0.850 F1=0.885
# epoch 57  loss=0.299908
#           val_loss=0.276356  Precision=0.905 Recall=0.881 F1=0.892
# epoch 58  loss=0.300417
#           val_loss=0.267722  Precision=0.922 Recall=0.845 F1=0.882
# epoch 59  loss=0.299606
#           val_loss=0.253392  Precision=0.926 Recall=0.846 F1=0.884
# epoch 60  loss=0.303611
#           val_loss=0.262755  Precision=0.898 Recall=0.901 F1=0.899
#           TEST -> loss=0.290801  Precision=0.881 Recall=0.862 F1=0.871
# epoch 61  loss=0.304143
#           val_loss=0.244005  Precision=0.916 Recall=0.862 F1=0.888
# epoch 62  loss=0.299025
#           val_loss=0.267646  Precision=0.910 Recall=0.851 F1=0.879
# epoch 63  loss=0.303992
#           val_loss=0.264967  Precision=0.887 Recall=0.860 F1=0.873
# epoch 64  loss=0.302678
#           val_loss=0.258445  Precision=0.908 Recall=0.873 F1=0.890
# epoch 65  loss=0.299429
#           val_loss=0.264650  Precision=0.894 Recall=0.890 F1=0.892
# epoch 66  loss=0.298527
#           val_loss=0.268843  Precision=0.901 Recall=0.872 F1=0.886
# epoch 67  loss=0.304656
#           val_loss=0.256275  Precision=0.914 Recall=0.849 F1=0.880
# epoch 68  loss=0.298891
#           val_loss=0.246738  Precision=0.919 Recall=0.886 F1=0.902
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.902)
# epoch 69  loss=0.295198
#           val_loss=0.262891  Precision=0.915 Recall=0.863 F1=0.888
# epoch 70  loss=0.297930
#           val_loss=0.265822  Precision=0.885 Recall=0.867 F1=0.876
#           TEST -> loss=0.256129  Precision=0.907 Recall=0.870 F1=0.888
# epoch 71  loss=0.297361
#           val_loss=0.248420  Precision=0.900 Recall=0.873 F1=0.886
# epoch 72  loss=0.297190
#           val_loss=0.262538  Precision=0.896 Recall=0.855 F1=0.875
# epoch 73  loss=0.294327
#           val_loss=0.238166  Precision=0.919 Recall=0.883 F1=0.901
# epoch 74  loss=0.288485
#           val_loss=0.257697  Precision=0.906 Recall=0.880 F1=0.893
# epoch 75  loss=0.294500
#           val_loss=0.253357  Precision=0.914 Recall=0.869 F1=0.891
# epoch 76  loss=0.289730
#           val_loss=0.257201  Precision=0.891 Recall=0.882 F1=0.886
# epoch 77  loss=0.293740
#           val_loss=0.263461  Precision=0.894 Recall=0.861 F1=0.877
# epoch 78  loss=0.295096
#           val_loss=0.256423  Precision=0.913 Recall=0.864 F1=0.888
# epoch 79  loss=0.291031
#           val_loss=0.253779  Precision=0.901 Recall=0.880 F1=0.890
# epoch 80  loss=0.294191
#           val_loss=0.257743  Precision=0.891 Recall=0.893 F1=0.892
#           TEST -> loss=0.265662  Precision=0.894 Recall=0.853 F1=0.873
# epoch 81  loss=0.301590
#           val_loss=0.260527  Precision=0.907 Recall=0.848 F1=0.877
# epoch 82  loss=0.293457
#           val_loss=0.249422  Precision=0.904 Recall=0.873 F1=0.888
# epoch 83  loss=0.294234
#           val_loss=0.272240  Precision=0.901 Recall=0.857 F1=0.878
# epoch 84  loss=0.288095
#           val_loss=0.255264  Precision=0.918 Recall=0.874 F1=0.896
# epoch 85  loss=0.292217
#           val_loss=0.236189  Precision=0.919 Recall=0.893 F1=0.905
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.905)
# epoch 86  loss=0.284923
#           val_loss=0.250587  Precision=0.918 Recall=0.864 F1=0.890
# epoch 87  loss=0.293466
#           val_loss=0.243420  Precision=0.929 Recall=0.881 F1=0.905
# epoch 88  loss=0.284977
#           val_loss=0.247683  Precision=0.912 Recall=0.874 F1=0.892
# epoch 89  loss=0.288357
#           val_loss=0.251989  Precision=0.940 Recall=0.857 F1=0.897
# epoch 90  loss=0.290788
#           val_loss=0.243353  Precision=0.934 Recall=0.860 F1=0.895
#           TEST -> loss=0.273129  Precision=0.879 Recall=0.851 F1=0.865
# epoch 91  loss=0.291905
#           val_loss=0.251337  Precision=0.903 Recall=0.881 F1=0.892
# epoch 92  loss=0.290324
#           val_loss=0.252201  Precision=0.925 Recall=0.859 F1=0.891
# epoch 93  loss=0.291126
#           val_loss=0.250205  Precision=0.914 Recall=0.857 F1=0.885
# epoch 94  loss=0.296212
#           val_loss=0.243793  Precision=0.909 Recall=0.895 F1=0.902
# epoch 95  loss=0.287998
#           val_loss=0.243023  Precision=0.903 Recall=0.869 F1=0.886
# epoch 96  loss=0.288616
#           val_loss=0.270146  Precision=0.910 Recall=0.854 F1=0.881
# epoch 97  loss=0.286380
#           val_loss=0.253080  Precision=0.901 Recall=0.862 F1=0.881
# epoch 98  loss=0.288327
#           val_loss=0.281850  Precision=0.911 Recall=0.837 F1=0.873
# epoch 99  loss=0.290873
#           val_loss=0.240935  Precision=0.913 Recall=0.867 F1=0.889
# epoch 100  loss=0.282697
#           val_loss=0.244504  Precision=0.910 Recall=0.876 F1=0.893
#           TEST -> loss=0.284085  Precision=0.875 Recall=0.858 F1=0.866
# epoch 101  loss=0.291822
#           val_loss=0.239518  Precision=0.933 Recall=0.864 F1=0.897
# epoch 102  loss=0.284558
#           val_loss=0.254962  Precision=0.903 Recall=0.858 F1=0.880
# epoch 103  loss=0.281675
#           val_loss=0.255997  Precision=0.927 Recall=0.851 F1=0.887
# epoch 104  loss=0.285138
#           val_loss=0.246076  Precision=0.923 Recall=0.867 F1=0.894
# epoch 105  loss=0.286197
#           val_loss=0.243202  Precision=0.885 Recall=0.899 F1=0.892
# epoch 106  loss=0.287563
#           val_loss=0.247312  Precision=0.926 Recall=0.859 F1=0.891
# epoch 107  loss=0.290308
#           val_loss=0.253455  Precision=0.933 Recall=0.857 F1=0.894
# epoch 108  loss=0.281592
#           val_loss=0.265144  Precision=0.887 Recall=0.862 F1=0.874
# epoch 109  loss=0.287982
#           val_loss=0.253697  Precision=0.919 Recall=0.863 F1=0.890
# epoch 110  loss=0.287892
#           val_loss=0.241707  Precision=0.911 Recall=0.880 F1=0.895
#           TEST -> loss=0.268450  Precision=0.889 Recall=0.878 F1=0.884
# epoch 111  loss=0.287366
#           val_loss=0.255236  Precision=0.919 Recall=0.841 F1=0.879
# epoch 112  loss=0.278947
#           val_loss=0.257005  Precision=0.892 Recall=0.872 F1=0.882
# epoch 113  loss=0.281399
#           val_loss=0.253137  Precision=0.924 Recall=0.853 F1=0.887
# epoch 114  loss=0.281634
#           val_loss=0.248596  Precision=0.889 Recall=0.890 F1=0.889
# epoch 115  loss=0.280334
#           val_loss=0.262255  Precision=0.920 Recall=0.858 F1=0.888
# epoch 116  loss=0.284616
#           val_loss=0.236564  Precision=0.931 Recall=0.865 F1=0.897
# epoch 117  loss=0.285994
#           val_loss=0.265924  Precision=0.911 Recall=0.864 F1=0.887
# epoch 118  loss=0.280191
#           val_loss=0.246919  Precision=0.910 Recall=0.869 F1=0.889
# epoch 119  loss=0.283535
#           val_loss=0.253679  Precision=0.928 Recall=0.842 F1=0.883
# epoch 120  loss=0.284676
#           val_loss=0.242128  Precision=0.909 Recall=0.875 F1=0.892
#           TEST -> loss=0.260634  Precision=0.880 Recall=0.889 F1=0.885
# epoch 121  loss=0.285071
#           val_loss=0.250908  Precision=0.914 Recall=0.867 F1=0.890
# epoch 122  loss=0.282383
#           val_loss=0.238768  Precision=0.902 Recall=0.894 F1=0.898
# epoch 123  loss=0.282424
#           val_loss=0.243076  Precision=0.914 Recall=0.851 F1=0.881
# epoch 124  loss=0.277919
#           val_loss=0.246594  Precision=0.898 Recall=0.879 F1=0.888
# epoch 125  loss=0.281615
#           val_loss=0.255494  Precision=0.921 Recall=0.856 F1=0.887
# epoch 126  loss=0.282333
#           val_loss=0.253020  Precision=0.902 Recall=0.878 F1=0.890
# epoch 127  loss=0.278837
#           val_loss=0.246903  Precision=0.904 Recall=0.866 F1=0.885
# epoch 128  loss=0.282200
#           val_loss=0.256702  Precision=0.927 Recall=0.854 F1=0.889
# epoch 129  loss=0.282181
#           val_loss=0.261878  Precision=0.898 Recall=0.868 F1=0.882
# epoch 130  loss=0.280726
#           val_loss=0.257053  Precision=0.911 Recall=0.863 F1=0.886
#           TEST -> loss=0.272644  Precision=0.887 Recall=0.859 F1=0.873
# epoch 131  loss=0.283063
#           val_loss=0.258563  Precision=0.895 Recall=0.870 F1=0.882
# epoch 132  loss=0.277253
#           val_loss=0.241547  Precision=0.940 Recall=0.863 F1=0.900
# epoch 133  loss=0.278383
#           val_loss=0.253149  Precision=0.918 Recall=0.845 F1=0.880
# epoch 134  loss=0.279370
#           val_loss=0.244881  Precision=0.910 Recall=0.884 F1=0.897
# epoch 135  loss=0.281560
#           val_loss=0.253506  Precision=0.933 Recall=0.851 F1=0.890
# epoch 136  loss=0.282309
#           val_loss=0.227992  Precision=0.907 Recall=0.889 F1=0.898
# epoch 137  loss=0.274814
#           val_loss=0.252380  Precision=0.915 Recall=0.866 F1=0.890
# epoch 138  loss=0.284208
#           val_loss=0.249248  Precision=0.927 Recall=0.855 F1=0.890
# epoch 139  loss=0.282494
#           val_loss=0.253919  Precision=0.902 Recall=0.875 F1=0.888
# epoch 140  loss=0.276749
#           val_loss=0.244136  Precision=0.916 Recall=0.869 F1=0.892
#           TEST -> loss=0.252430  Precision=0.898 Recall=0.866 F1=0.882
# epoch 141  loss=0.278875
#           val_loss=0.259951  Precision=0.918 Recall=0.856 F1=0.886
# epoch 142  loss=0.276875
#           val_loss=0.251156  Precision=0.904 Recall=0.857 F1=0.880
# epoch 143  loss=0.278834
#           val_loss=0.239733  Precision=0.885 Recall=0.893 F1=0.889
# epoch 144  loss=0.270185
#           val_loss=0.229039  Precision=0.918 Recall=0.894 F1=0.906
#   saved best -> Models/single_voice_tcn_20260301_181247_670487.pt (best_val_f1=0.906)
# epoch 145  loss=0.276986
#           val_loss=0.241465  Precision=0.922 Recall=0.871 F1=0.896
# epoch 146  loss=0.278892
#           val_loss=0.235243  Precision=0.927 Recall=0.869 F1=0.897
# epoch 147  loss=0.279036
#           val_loss=0.244074  Precision=0.902 Recall=0.878 F1=0.890
# epoch 148  loss=0.277744
#           val_loss=0.238947  Precision=0.904 Recall=0.878 F1=0.891
# epoch 149  loss=0.277169
#           val_loss=0.238039  Precision=0.929 Recall=0.850 F1=0.888
# epoch 150  loss=0.275436
#           val_loss=0.238874  Precision=0.895 Recall=0.865 F1=0.880
#           TEST -> loss=0.264004  Precision=0.888 Recall=0.863 F1=0.875
# epoch 151  loss=0.278743
#           val_loss=0.248770  Precision=0.887 Recall=0.872 F1=0.880
# epoch 152  loss=0.278993
#           val_loss=0.239921  Precision=0.926 Recall=0.858 F1=0.891
# epoch 153  loss=0.280377
#           val_loss=0.234425  Precision=0.912 Recall=0.877 F1=0.894
# epoch 154  loss=0.275637
#           val_loss=0.249206  Precision=0.914 Recall=0.877 F1=0.895
# epoch 155  loss=0.282659
#           val_loss=0.256002  Precision=0.927 Recall=0.845 F1=0.884
# epoch 156  loss=0.274954
#           val_loss=0.260596  Precision=0.896 Recall=0.877 F1=0.887
# epoch 157  loss=0.276352
#           val_loss=0.237768  Precision=0.935 Recall=0.861 F1=0.896
# epoch 158  loss=0.273676
#           val_loss=0.239613  Precision=0.896 Recall=0.870 F1=0.883
# epoch 159  loss=0.278648
#           val_loss=0.238241  Precision=0.893 Recall=0.889 F1=0.891
# epoch 160  loss=0.276137
#           val_loss=0.235102  Precision=0.914 Recall=0.882 F1=0.898
#           TEST -> loss=0.273968  Precision=0.918 Recall=0.839 F1=0.877
# epoch 161  loss=0.278302
#           val_loss=0.250806  Precision=0.927 Recall=0.858 F1=0.891
# epoch 162  loss=0.277371
#           val_loss=0.245203  Precision=0.922 Recall=0.853 F1=0.886
# epoch 163  loss=0.273619
#           val_loss=0.247152  Precision=0.938 Recall=0.854 F1=0.895
# epoch 164  loss=0.278219
#           val_loss=0.243981  Precision=0.918 Recall=0.869 F1=0.893
# epoch 165  loss=0.280403
#           val_loss=0.244487  Precision=0.920 Recall=0.849 F1=0.883
# epoch 166  loss=0.272644
#           val_loss=0.239809  Precision=0.916 Recall=0.866 F1=0.891
# epoch 167  loss=0.271762
#           val_loss=0.235444  Precision=0.913 Recall=0.870 F1=0.891
# epoch 168  loss=0.276362
#           val_loss=0.236179  Precision=0.923 Recall=0.887 F1=0.904
# epoch 169  loss=0.270556
#           val_loss=0.241707  Precision=0.907 Recall=0.868 F1=0.887
# epoch 170  loss=0.276828
#           val_loss=0.229707  Precision=0.918 Recall=0.879 F1=0.898
#           TEST -> loss=0.251377  Precision=0.913 Recall=0.854 F1=0.882
# epoch 171  loss=0.272203
#           val_loss=0.243714  Precision=0.885 Recall=0.893 F1=0.889
# epoch 172  loss=0.280820
#           val_loss=0.245890  Precision=0.924 Recall=0.851 F1=0.886
# epoch 173  loss=0.275330
#           val_loss=0.250080  Precision=0.925 Recall=0.861 F1=0.892
# epoch 174  loss=0.277290
#           val_loss=0.248442  Precision=0.910 Recall=0.890 F1=0.900
# epoch 175  loss=0.274901
#           val_loss=0.246257  Precision=0.906 Recall=0.864 F1=0.885
# epoch 176  loss=0.269172
#           val_loss=0.245607  Precision=0.884 Recall=0.891 F1=0.887
# epoch 177  loss=0.272328
#           val_loss=0.243773  Precision=0.897 Recall=0.872 F1=0.884
# epoch 178  loss=0.270806
#           val_loss=0.248509  Precision=0.919 Recall=0.858 F1=0.887
# epoch 179  loss=0.270268
#           val_loss=0.244903  Precision=0.922 Recall=0.874 F1=0.897
# epoch 180  loss=0.274040
#           val_loss=0.250442  Precision=0.941 Recall=0.841 F1=0.888
#           TEST -> loss=0.290473  Precision=0.904 Recall=0.804 F1=0.851
# epoch 181  loss=0.272982
#           val_loss=0.242076  Precision=0.895 Recall=0.878 F1=0.887
# epoch 182  loss=0.274977
#           val_loss=0.242201  Precision=0.922 Recall=0.845 F1=0.882
# epoch 183  loss=0.268600
#           val_loss=0.234843  Precision=0.915 Recall=0.867 F1=0.890
# epoch 184  loss=0.272967
#           val_loss=0.240324  Precision=0.921 Recall=0.860 F1=0.890
# epoch 185  loss=0.269751
#           val_loss=0.236496  Precision=0.910 Recall=0.885 F1=0.897
# epoch 186  loss=0.268728
#           val_loss=0.223093  Precision=0.913 Recall=0.891 F1=0.902
# epoch 187  loss=0.269404
#           val_loss=0.250485  Precision=0.921 Recall=0.843 F1=0.880
# epoch 188  loss=0.272792
#           val_loss=0.236540  Precision=0.914 Recall=0.874 F1=0.894
# epoch 189  loss=0.276111
#           val_loss=0.237822  Precision=0.918 Recall=0.888 F1=0.903
# epoch 190  loss=0.270257
#           val_loss=0.235574  Precision=0.909 Recall=0.877 F1=0.893
#           TEST -> loss=0.255629  Precision=0.900 Recall=0.854 F1=0.877
# epoch 191  loss=0.273345
#           val_loss=0.259214  Precision=0.929 Recall=0.847 F1=0.886
# epoch 192  loss=0.279352
#           val_loss=0.241671  Precision=0.902 Recall=0.883 F1=0.892
# epoch 193  loss=0.268552
#           val_loss=0.261031  Precision=0.943 Recall=0.824 F1=0.879
# epoch 194  loss=0.276013
#           val_loss=0.234523  Precision=0.926 Recall=0.874 F1=0.899
# epoch 195  loss=0.268765
#           val_loss=0.244388  Precision=0.885 Recall=0.901 F1=0.893
# epoch 196  loss=0.268104
#           val_loss=0.237943  Precision=0.925 Recall=0.854 F1=0.888
# epoch 197  loss=0.278091
#           val_loss=0.232843  Precision=0.930 Recall=0.861 F1=0.894
# epoch 198  loss=0.270013
#           val_loss=0.246317  Precision=0.900 Recall=0.874 F1=0.887
# epoch 199  loss=0.266408
#           val_loss=0.237341  Precision=0.924 Recall=0.876 F1=0.900
# epoch 200  loss=0.263191
#           val_loss=0.248022  Precision=0.905 Recall=0.856 F1=0.880
#           TEST -> loss=0.256401  Precision=0.905 Recall=0.848 F1=0.875
# epoch 201  loss=0.261800
#           val_loss=0.227165  Precision=0.930 Recall=0.875 F1=0.902
# epoch 202  loss=0.270518
#           val_loss=0.251760  Precision=0.901 Recall=0.870 F1=0.885
# epoch 203  loss=0.273550
#           val_loss=0.234821  Precision=0.929 Recall=0.878 F1=0.903
# epoch 204  loss=0.278103
#           val_loss=0.242300  Precision=0.918 Recall=0.872 F1=0.895
# epoch 205  loss=0.268126
#           val_loss=0.242699  Precision=0.900 Recall=0.892 F1=0.896
# epoch 206  loss=0.269667
#           val_loss=0.247303  Precision=0.931 Recall=0.843 F1=0.885
# epoch 207  loss=0.271249
#           val_loss=0.243729  Precision=0.920 Recall=0.854 F1=0.886
# epoch 208  loss=0.271996
#           val_loss=0.239404  Precision=0.901 Recall=0.881 F1=0.891
# epoch 209  loss=0.269990
#           val_loss=0.221958  Precision=0.913 Recall=0.873 F1=0.893
# epoch 210  loss=0.266198
#           val_loss=0.232124  Precision=0.934 Recall=0.857 F1=0.894
#           TEST -> loss=0.269390  Precision=0.914 Recall=0.833 F1=0.872
# epoch 211  loss=0.272431
#           val_loss=0.239365  Precision=0.916 Recall=0.869 F1=0.892
# epoch 212  loss=0.268146
#           val_loss=0.230849  Precision=0.914 Recall=0.882 F1=0.898
# epoch 213  loss=0.267229
#           val_loss=0.256448  Precision=0.918 Recall=0.846 F1=0.880
# epoch 214  loss=0.269969
#           val_loss=0.230104  Precision=0.907 Recall=0.892 F1=0.900
# epoch 215  loss=0.261264
#           val_loss=0.230138  Precision=0.913 Recall=0.875 F1=0.894
# epoch 216  loss=0.265571
#           val_loss=0.232594  Precision=0.918 Recall=0.879 F1=0.898
# epoch 217  loss=0.272860
#           val_loss=0.249059  Precision=0.904 Recall=0.876 F1=0.890
# epoch 218  loss=0.266798
#           val_loss=0.237325  Precision=0.929 Recall=0.867 F1=0.897
# epoch 219  loss=0.264364
#           val_loss=0.236297  Precision=0.923 Recall=0.878 F1=0.900
# epoch 220  loss=0.270491
#           val_loss=0.254481  Precision=0.909 Recall=0.857 F1=0.882
#           TEST -> loss=0.268749  Precision=0.924 Recall=0.834 F1=0.876
# epoch 221  loss=0.267576
#           val_loss=0.253501  Precision=0.909 Recall=0.857 F1=0.882
# epoch 222  loss=0.269229
#           val_loss=0.235137  Precision=0.911 Recall=0.885 F1=0.898
# epoch 223  loss=0.271733
#           val_loss=0.234866  Precision=0.932 Recall=0.860 F1=0.894
# epoch 224  loss=0.268641
#           val_loss=0.241298  Precision=0.906 Recall=0.881 F1=0.893
# epoch 225  loss=0.267502
#           val_loss=0.235635  Precision=0.913 Recall=0.878 F1=0.896
# epoch 226  loss=0.266418
#           val_loss=0.226072  Precision=0.923 Recall=0.870 F1=0.896
# epoch 227  loss=0.265019
#           val_loss=0.232767  Precision=0.938 Recall=0.861 F1=0.898
# epoch 228  loss=0.267701
#           val_loss=0.240848  Precision=0.919 Recall=0.881 F1=0.900
# epoch 229  loss=0.267400
#           val_loss=0.226911  Precision=0.928 Recall=0.868 F1=0.897
# epoch 230  loss=0.267678
#           val_loss=0.230489  Precision=0.918 Recall=0.874 F1=0.895
#           TEST -> loss=0.263016  Precision=0.906 Recall=0.849 F1=0.877
# epoch 231  loss=0.263404
#           val_loss=0.235235  Precision=0.922 Recall=0.874 F1=0.897

# %%
# For testing inferrence

# Sample a new 8-bar pattern (T is now inferred from loaded data)
# h, v = sample_pattern(
#     model,
#     T=T,
#     n_iters=16,
#     device="mps",
#     density_bias=0.0,      # + => busier, - => sparser, range of [-3, 3]
#     sigma_floor=0.08,      # higher => more velocity variation
#     resample_fraction=0.45,
#     temperature_hit=1.0,
# )

# print("hit:", h.numpy().astype(int).tolist())
# midi_vel = (v.numpy() * 127.0).round().astype(int).tolist()
# print("vel:", midi_vel)

# out_path = export_single_voice_steps_to_midi(
#     hit=h.numpy(),
#     vel=v.numpy(),
#     out_dir="./generated_midis",
#     cfg=cfg_out,
# )

# print("Saved MIDI:", out_path)

# %%
# Inspect a midi file

# import mido
# from collections import Counter

# def inspect_midi(path: str, max_print: int = 10):
#     mid = mido.MidiFile(path)
#     print("ticks_per_beat:", mid.ticks_per_beat)

#     pitch_counts = Counter()
#     chan_counts = Counter()
#     events = 0

#     for tr_i, track in enumerate(mid.tracks):
#         abs_tick = 0
#         for msg in track:
#             abs_tick += msg.time
#             if msg.type == "note_on" and msg.velocity > 0:
#                 events += 1
#                 chan = getattr(msg, "channel", None)
#                 pitch_counts[msg.note] += 1
#                 chan_counts[chan] += 1

#     print("note_on events:", events)
#     print("top pitches:", pitch_counts.most_common(max_print))
#     print("channels:", chan_counts.most_common())

# inspect_midi("MIDI/1hit.mid")
