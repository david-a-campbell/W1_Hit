# %%
# hit_generator.py
# Single-voice drum step generator (16th-note grid) with continuous velocity
# IMPORTANT: training data is loaded as (file, pitch) records via MultiVoiceMidiDataset
# so each sample is ONE pitch lane, not a whole multi-pitch MIDI file.

from __future__ import annotations

import subprocess
import signal
import sys
import os
import random
from dataclasses import dataclass
from datetime import datetime
from typing import Dict, Tuple, Optional, List

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

from mid_to_velocity import MidiGridConfig, MultiVoiceMidiDataset
from midi_export import export_single_voice_steps_to_midi, MidiExportConfig


# ----------------------------
# Utils
# ----------------------------

def set_seed(seed: int = 42) -> None:
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def circular_pad_1d(x: torch.Tensor, pad: int) -> torch.Tensor:
    """
    Circular padding for 1D conv.
    x: (B, C, T)
    """
    if pad <= 0:
        return x
    return torch.cat([x[..., -pad:], x, x[..., :pad]], dim=-1)


def masked_huber(pred: torch.Tensor, target: torch.Tensor, mask: torch.Tensor, delta: float = 0.1) -> torch.Tensor:
    """
    pred/target: (B, T)
    mask: (B, T) in {0,1} or [0,1]
    """
    loss = F.smooth_l1_loss(pred, target, reduction="none", beta=delta)  # (B, T)
    denom = mask.sum().clamp_min(1.0)
    return (loss * mask).sum() / denom


def _ensure_pt_name(name: str) -> str:
    return name if name.endswith(".pt") else (name + ".pt")


def make_unique_model_name(prefix: str = "single_voice_tcn") -> str:
    # Example: single_voice_tcn_20260226_153012_482931
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    suffix = f"{random.randint(0, 999999):06d}"
    return f"{prefix}_{ts}_{suffix}"


# ----------------------------
# Model: TCN with circular padding
# ----------------------------

class CircularConv1d(nn.Module):
    def __init__(self, in_ch: int, out_ch: int, kernel_size: int, dilation: int):
        super().__init__()
        assert kernel_size % 2 == 1, "Use odd kernel size for 'same' length."
        self.kernel_size = kernel_size
        self.dilation = dilation
        self.conv = nn.Conv1d(
            in_channels=in_ch,
            out_channels=out_ch,
            kernel_size=kernel_size,
            dilation=dilation,
            padding=0,  # manual circular padding
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        pad = self.dilation * (self.kernel_size - 1) // 2
        x = circular_pad_1d(x, pad)
        return self.conv(x)


class TCNBlock(nn.Module):
    def __init__(self, channels: int, kernel_size: int, dilation: int, dropout: float = 0.1):
        super().__init__()
        self.conv1 = CircularConv1d(channels, channels, kernel_size=kernel_size, dilation=dilation)
        self.conv2 = CircularConv1d(channels, channels, kernel_size=kernel_size, dilation=dilation)
        self.dropout = nn.Dropout(dropout)
        self.norm1 = nn.GroupNorm(num_groups=8 if channels >= 8 else 1, num_channels=channels)
        self.norm2 = nn.GroupNorm(num_groups=8 if channels >= 8 else 1, num_channels=channels)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        residual = x

        x = self.conv1(x)
        x = self.norm1(x)
        x = F.gelu(x)
        x = self.dropout(x)

        x = self.conv2(x)
        x = self.norm2(x)
        x = F.gelu(x)
        x = self.dropout(x)

        return x + residual


class SingleVoiceTCN(nn.Module):
    """
    Input per step:
      - hit_in (0/1, possibly corrupted)
      - vel_in (0..1, possibly corrupted)
      - mask_in (1 if masked/unknown, 0 if known)
    x: (B, 3, T)

    Output (SINGLE PITCH GRID):
      - hit_logits: (B, T)
      - vel_mu: (B, T) in [0,1]
      - vel_log_sigma: (B, T) optional
    """

    def __init__(
        self,
        in_channels: int = 3,
        hidden: int = 128,
        kernel_size: int = 3,
        dilations: Tuple[int, ...] = (1, 2, 4, 8, 16, 1, 2, 4),
        dropout: float = 0.1,
        predict_sigma: bool = True,
    ):
        super().__init__()
        self.predict_sigma = predict_sigma

        self.in_proj = nn.Conv1d(in_channels, hidden, kernel_size=1)
        self.blocks = nn.ModuleList([TCNBlock(hidden, kernel_size=kernel_size, dilation=d, dropout=dropout) for d in dilations])

        self.hit_head = nn.Conv1d(hidden, 1, kernel_size=1)  # logits
        self.vel_head = nn.Conv1d(hidden, 1, kernel_size=1)  # mu -> sigmoid

        self.sigma_head = nn.Conv1d(hidden, 1, kernel_size=1) if predict_sigma else None

    def forward(self, x: torch.Tensor) -> Dict[str, torch.Tensor]:
        h = self.in_proj(x)
        for blk in self.blocks:
            h = blk(h)

        hit_logits = self.hit_head(h).squeeze(1)                 # (B, T)
        vel_mu = torch.sigmoid(self.vel_head(h).squeeze(1))      # (B, T)

        out = {"hit_logits": hit_logits, "vel_mu": vel_mu}
        if self.predict_sigma and self.sigma_head is not None:
            out["vel_log_sigma"] = self.sigma_head(h).squeeze(1) # (B, T)

        return out


# ----------------------------
# Masking / corruption for denoising
# ----------------------------

@dataclass
class MaskConfig:
    p_mask: float = 0.5
    p_flip_hit: float = 0.0
    p_jitter_vel: float = 0.0


def corrupt_inputs(
    hit: torch.Tensor,  # (B,T)
    vel: torch.Tensor,  # (B,T)
    cfg: MaskConfig,
) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
    """
    Returns: hit_in, vel_in, mask (1 where masked)
    """
    B, T = hit.shape
    device = hit.device

    mask = (torch.rand((B, T), device=device) < cfg.p_mask).float()

    hit_in = hit.clone()
    vel_in = vel.clone()

    # masked steps -> 0, model uses mask channel to know it's unknown
    hit_in = hit_in * (1.0 - mask)
    vel_in = vel_in * (1.0 - mask)

    # optional corruption on known steps
    if cfg.p_flip_hit > 0.0:
        flip = ((torch.rand((B, T), device=device) < cfg.p_flip_hit).float()) * (1.0 - mask)
        hit_in = torch.where(flip > 0.0, 1.0 - hit_in, hit_in)

    if cfg.p_jitter_vel > 0.0:
        noise = torch.randn((B, T), device=device) * cfg.p_jitter_vel
        vel_in = torch.clamp(vel_in + noise * (1.0 - mask), 0.0, 1.0)

    return hit_in, vel_in, mask


# ----------------------------
# DATA LOADING (FIXED): per-pitch samples, not per-file
# ----------------------------

def load_training_tensors(
    midi_dir: str,
    cfg: MidiGridConfig,
    *,
    batch_size: int = 256,
    min_hits_per_voice: int = 1,
    max_hits_per_voice: Optional[int] = None,
    device: str = "cpu",
) -> Tuple[torch.Tensor, torch.Tensor]:
    """
    Returns:
      data_hit: (N, T)
      data_vel: (N, T)

    N counts *pitches*, not files:
    MultiVoiceMidiDataset indexes (file, pitch) pairs and each item returns
    one pitch-lane grid. (This is the core fix.)
    """
    ds = MultiVoiceMidiDataset(
        midi_dir,
        cfg,
        min_hits_per_voice=min_hits_per_voice,
        max_hits_per_voice=max_hits_per_voice,
        include_pitch=False,  # pitch not needed for training
    )

    dl = DataLoader(ds, batch_size=batch_size, shuffle=True, drop_last=False)

    all_hit: List[torch.Tensor] = []
    all_vel: List[torch.Tensor] = []

    for batch in dl:
        # batch["hit"], batch["vel"] : (B, T)
        all_hit.append(batch["hit"])
        all_vel.append(batch["vel"])

    data_hit = torch.cat(all_hit, dim=0).float().to(device)
    data_vel = torch.cat(all_vel, dim=0).float().to(device)

    return data_hit, data_vel


# ----------------------------
# Saving / Loading
# ----------------------------

def save_model(
    model: nn.Module,
    path: str,
    *,
    model_config: Optional[dict] = None,
    best_loss: Optional[float] = None,
    best_f1: Optional[float] = None,
) -> None:
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    torch.save(
        {
            "model_state_dict": model.state_dict(),
            "model_config": model_config,
            "best_loss": best_loss,
            "best_f1": best_f1,
        },
        path,
    )


def load_checkpoint(path: str, device: str = "cpu") -> dict:
    if not os.path.exists(path):
        raise FileNotFoundError(f"Checkpoint not found: {path}")
    return torch.load(path, map_location=torch.device(device), weights_only = True)

# ----------------------------
# Split the data into training / testing
# ----------------------------

def split_tensors(
    data_hit: torch.Tensor,
    data_vel: torch.Tensor,
    train_frac: float = 0.8,
    val_frac: float = 0.1,
    seed: int = 42,
) -> tuple[tuple[torch.Tensor, torch.Tensor], tuple[torch.Tensor, torch.Tensor], tuple[torch.Tensor, torch.Tensor]]:
    assert 0 < train_frac < 1 and 0 <= val_frac < 1 and train_frac + val_frac < 1
    N = data_hit.shape[0]
    g = torch.Generator(device=data_hit.device)
    g.manual_seed(seed)
    idx = torch.randperm(N, generator=g, device=data_hit.device)

    n_train = int(N * train_frac)
    n_val = int(N * val_frac)
    train_idx = idx[:n_train]
    val_idx = idx[n_train:n_train + n_val]
    test_idx = idx[n_train + n_val:]

    return (
        (data_hit[train_idx], data_vel[train_idx]),
        (data_hit[val_idx], data_vel[val_idx]),
        (data_hit[test_idx], data_vel[test_idx]),
    )

# ----------------------------
# Evaluate model for accuracy
# ----------------------------

@torch.no_grad()
def evaluate_denoise(
    model: nn.Module,
    data_hit: torch.Tensor,
    data_vel: torch.Tensor,
    *,
    batch_size: int,
    device: str,
    mask_cfg: MaskConfig,
    lambda_vel: float,
) -> tuple[float, float, float, float]:
    """
    Returns: (avg_loss, hit_accuracy_on_masked_steps)
    """
    device_t = torch.device(device)
    model.eval()

    data_hit = data_hit.to(device_t)
    data_vel = data_vel.to(device_t)

    N, T = data_hit.shape
    total_loss = 0.0
    total_seen = 0

    TP = FP = FN = TN = 0.0

    for i in range(0, N, batch_size):
        hit = data_hit[i:i + batch_size]
        vel = data_vel[i:i + batch_size]

        hit_in, vel_in, mask = corrupt_inputs(hit, vel, mask_cfg)
        x = torch.stack([hit_in, vel_in, mask], dim=1)  # (B,3,T)
        out = model(x)

        # same loss as training (masked-only)
        hit_loss = F.binary_cross_entropy_with_logits(out["hit_logits"], hit, reduction="none")
        hit_loss = (hit_loss * mask).sum() / mask.sum().clamp_min(1.0)

        vel_mask = mask * hit
        vel_loss = masked_huber(out["vel_mu"], vel, vel_mask, delta=0.1)

        loss = hit_loss + lambda_vel * vel_loss

        bs = hit.shape[0]
        total_loss += float(loss.item()) * bs
        total_seen += bs

        # hit accuracy on masked steps
        pred = (torch.sigmoid(out["hit_logits"]) > 0.5).float()

        # Only evaluate on masked steps
        m = mask > 0.0
        y = hit.float()

        tp = ((pred == 1) & (y == 1) & m).sum().item()
        fp = ((pred == 1) & (y == 0) & m).sum().item()
        fn = ((pred == 0) & (y == 1) & m).sum().item()
        tn = ((pred == 0) & (y == 0) & m).sum().item()

        TP += tp; FP += fp; FN += fn; TN += tn

    avg_loss = total_loss / max(1, total_seen)
    precision = TP / max(1e-9, (TP + FP))
    recall    = TP / max(1e-9, (TP + FN))
    f1        = 2 * precision * recall / max(1e-9, (precision + recall))
    return avg_loss, precision, recall, f1
    
# ----------------------------
# Training
# ----------------------------

def train(
    model: nn.Module,
    data_hit: torch.Tensor,   # (N, T)
    data_vel: torch.Tensor,   # (N, T)
    *,
    val_hit: Optional[torch.Tensor] = None,
    val_vel: Optional[torch.Tensor] = None,
    test_hit: Optional[torch.Tensor] = None,
    test_vel: Optional[torch.Tensor] = None,
    epochs: Optional[int] = 20,
    batch_size: int = 128,
    lr: float = 2e-3,
    device: str = "cpu",
    mask_cfg: MaskConfig = MaskConfig(p_mask=0.5),
    lambda_vel: float = 1.0,
    save_best_path: Optional[str] = None,
    model_config: Optional[dict] = None,
    best_init: float = -1.0,   # best F1 so far
) -> float:
    device_t = torch.device(device)
    model.to(device_t)

    # move data if needed
    data_hit = data_hit.to(device_t)
    data_vel = data_vel.to(device_t)

    opt = torch.optim.AdamW(model.parameters(), lr=lr)
    best_f1 = float(best_init)

    N, T = data_hit.shape

    # simple minibatching from tensors
    def batches():
        idx = torch.randperm(N, device=device_t)
        for i in range(0, N, batch_size):
            j = idx[i:i + batch_size]
            yield data_hit[j], data_vel[j]

    epoch = 0
    while True:
        if epochs is not None and epoch >= epochs:
            break

        model.train()
        running = 0.0
        n_seen = 0

        for hit, vel in batches():
            hit_in, vel_in, mask = corrupt_inputs(hit, vel, mask_cfg)

            x = torch.stack([hit_in, vel_in, mask], dim=1)  # (B, 3, T)
            out = model(x)

            # hit loss on masked steps only
            hit_loss = F.binary_cross_entropy_with_logits(out["hit_logits"], hit, reduction="none")
            hit_loss = (hit_loss * mask).sum() / mask.sum().clamp_min(1.0)

            # velocity loss only on masked steps (and only where there is a hit)
            vel_mask = mask * hit  # only care vel where a hit exists
            vel_loss = masked_huber(out["vel_mu"], vel, vel_mask, delta=0.1)

            loss = hit_loss + lambda_vel * vel_loss

            opt.zero_grad(set_to_none=True)
            loss.backward()
            opt.step()

            running += float(loss.item()) * hit.shape[0]
            n_seen += hit.shape[0]

        epoch_loss = running / max(1, n_seen)
        print(f"epoch {epoch}  loss={epoch_loss:.6f}")

        # ---- VALIDATION (used for checkpointing) ----
        if val_hit is not None and val_vel is not None:
            val_loss, precision, recall, val_f1 = evaluate_denoise(
                model,
                val_hit,
                val_vel,
                batch_size=batch_size,
                device=device,
                mask_cfg=mask_cfg,
                lambda_vel=lambda_vel,
            )
        
            print(f"          val_loss={val_loss:.6f}  Precision={precision:.3f} Recall={recall:.3f} F1={val_f1:.3f}")
        
            if save_best_path is not None and val_f1 > best_f1:
                best_f1 = val_f1
                save_model(
                    model,
                    path=save_best_path,
                    model_config=model_config,
                    best_loss=val_loss,
                    best_f1=best_f1,
                )
                print(f"  saved best -> {save_best_path} (best_val_f1={best_f1:.3f})")
        
        # ---- TEST (report only) ----
        if test_hit is not None and test_vel is not None and (epoch % 10 == 0):
            test_loss, tprec, trec, test_f1 = evaluate_denoise(
                model,
                test_hit,
                test_vel,
                batch_size=batch_size,
                device=device,
                mask_cfg=mask_cfg,
                lambda_vel=lambda_vel,
            )
            print(f"          TEST -> loss={test_loss:.6f}  Precision={tprec:.3f} Recall={trec:.3f} F1={test_f1:.3f}")
    
        epoch += 1

    return best_f1


# ----------------------------
# Example main
# ----------------------------

if __name__ == "__main__":
    set_seed(42)

    cfg = MidiGridConfig(
        bars=8,
        steps_per_bar=16,
        drum_channel=None,
        voice_pitch=None,          # ignored by MultiVoiceMidiDataset indexing
        step_merge="max",
        quantize="nearest",
        align_first_hit_to_zero=False,
    )

    device = "cpu"
    data_hit, data_vel = load_training_tensors(
        midi_dir="MIDI",
        cfg=cfg,
        batch_size=256,
        min_hits_per_voice=4,
        max_hits_per_voice=64,
        device=device,
    )
    N, T = data_hit.shape
    print("Loaded per-pitch samples:", (N, T))

    (train_hit, train_vel), (val_hit, val_vel), (test_hit, test_vel) = split_tensors(
        data_hit, data_vel, train_frac=0.8, val_frac=0.1, seed=42
    )
    print(f"Split: train={train_hit.shape[0]}  val={val_hit.shape[0]}  test={test_hit.shape[0]}")

    
    # Pass a filename (e.g. "candidate.pt" or "candidate") to resume.
    # Pass None to start a new run with a unique filename.
    resume_name: Optional[str] = None  # e.g. "single_voice_tcn_20260226_153012_482931" or "candidate.pt"

    default_model_cfg = {
        "in_channels": 3,
        "hidden": 64,
        "kernel_size": 3,
        "dilations": (1, 2, 4, 8, 16, 1, 2, 4),
        "dropout": 0.1,
        "predict_sigma": True,
    }

    best_init: float = -1.0

    if resume_name is not None:
        ckpt_path = os.path.join("Models", _ensure_pt_name(resume_name))
        ckpt = load_checkpoint(ckpt_path, device=device)
        model_cfg = ckpt.get("model_config") or default_model_cfg
        model = SingleVoiceTCN(**model_cfg)
        model.load_state_dict(ckpt["model_state_dict"])
        best_init = float(ckpt.get("best_f1", -1.0))
        model_name = os.path.splitext(os.path.basename(ckpt_path))[0]
        best_path = ckpt_path
        print(f"Resuming from: {best_path} (prev_best_f1={best_init if best_init >= 0.0 else 'unknown'})")
    else:
        model_cfg = default_model_cfg
        model = SingleVoiceTCN(**model_cfg)
        model_name = make_unique_model_name(prefix="single_voice_tcn")
        best_path = os.path.join("Models", _ensure_pt_name(model_name))
        print(f"Starting new run: {best_path}")

    caff = None
    
    try:
        caff = subprocess.Popen(["caffeinate", "-dimsu"])
    
        train(
            model=model,
            data_hit=train_hit,
            data_vel=train_vel,
            val_hit=val_hit,
            val_vel=val_vel,
            test_hit=test_hit,
            test_vel=test_vel,
            epochs=None,
            batch_size=128,
            lr=2e-3,
            device=device,
            mask_cfg=MaskConfig(p_mask=0.55),
            lambda_vel=1.5,
            save_best_path=best_path,
            model_config=model_cfg,
            best_init=best_init,
        )
        
    except KeyboardInterrupt:
        print("\nStopped by user. Done.")
    finally:
        if caff is not None:
            caff.terminate()
            caff.wait()
# Out:
# Loaded per-pitch samples: (663, 128)
# Split: train=530  val=66  test=67
# Starting new run: Models/single_voice_tcn_20260301_134903_670487.pt
# epoch 0  loss=1.624166
#           test_loss=1.114179  Precision=0.375 Recall=0.840 F1=0.519
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=1.624166)
# epoch 1  loss=0.866226
#           test_loss=0.771249  Precision=1.000 Recall=0.003 F1=0.007
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.866226)
# epoch 2  loss=0.720990
#           test_loss=0.670162  Precision=0.825 Recall=0.539 F1=0.652
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.720990)
# epoch 3  loss=0.620102
#           test_loss=0.568709  Precision=0.874 Recall=0.554 F1=0.678
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.620102)
# epoch 4  loss=0.547568
#           test_loss=0.517930  Precision=0.811 Recall=0.722 F1=0.764
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.547568)
# epoch 5  loss=0.507731
#           test_loss=0.509976  Precision=0.857 Recall=0.660 F1=0.745
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.507731)
# epoch 6  loss=0.481030
#           test_loss=0.466856  Precision=0.841 Recall=0.785 F1=0.812
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.481030)
# epoch 7  loss=0.464702
#           test_loss=0.451369  Precision=0.879 Recall=0.753 F1=0.811
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.464702)
# epoch 8  loss=0.451138
#           test_loss=0.438158  Precision=0.853 Recall=0.798 F1=0.825
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.451138)
# epoch 9  loss=0.445848
#           test_loss=0.435735  Precision=0.866 Recall=0.799 F1=0.831
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.445848)
# epoch 10  loss=0.437837
#           test_loss=0.432003  Precision=0.849 Recall=0.794 F1=0.821
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.437837)
# epoch 11  loss=0.426123
#           test_loss=0.445642  Precision=0.864 Recall=0.779 F1=0.819
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.426123)
# epoch 12  loss=0.421625
#           test_loss=0.415022  Precision=0.869 Recall=0.805 F1=0.836
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.421625)
# epoch 13  loss=0.416258
#           test_loss=0.404118  Precision=0.885 Recall=0.786 F1=0.833
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.416258)
# epoch 14  loss=0.410263
#           test_loss=0.415045  Precision=0.849 Recall=0.834 F1=0.842
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.410263)
# epoch 15  loss=0.410617
#           test_loss=0.385940  Precision=0.874 Recall=0.786 F1=0.828
# epoch 16  loss=0.394925
#           test_loss=0.402987  Precision=0.864 Recall=0.784 F1=0.822
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.394925)
# epoch 17  loss=0.397602
#           test_loss=0.400603  Precision=0.857 Recall=0.809 F1=0.832
# epoch 18  loss=0.373539
#           test_loss=0.361656  Precision=0.868 Recall=0.834 F1=0.851
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.373539)
# epoch 19  loss=0.367892
#           test_loss=0.382746  Precision=0.888 Recall=0.762 F1=0.820
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.367892)
# epoch 20  loss=0.352746
#           test_loss=0.357502  Precision=0.856 Recall=0.811 F1=0.833
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.352746)
# epoch 21  loss=0.350741
#           test_loss=0.361654  Precision=0.870 Recall=0.814 F1=0.841
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.350741)
# epoch 22  loss=0.349304
#           test_loss=0.335350  Precision=0.847 Recall=0.821 F1=0.834
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.349304)
# epoch 23  loss=0.342102
#           test_loss=0.338720  Precision=0.889 Recall=0.802 F1=0.843
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.342102)
# epoch 24  loss=0.339041
#           test_loss=0.343850  Precision=0.882 Recall=0.796 F1=0.837
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.339041)
# epoch 25  loss=0.341551
#           test_loss=0.348953  Precision=0.847 Recall=0.823 F1=0.835
# epoch 26  loss=0.337611
#           test_loss=0.320652  Precision=0.852 Recall=0.823 F1=0.837
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.337611)
# epoch 27  loss=0.329964
#           test_loss=0.342993  Precision=0.874 Recall=0.808 F1=0.840
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.329964)
# epoch 28  loss=0.332717
#           test_loss=0.400619  Precision=0.816 Recall=0.842 F1=0.829
# epoch 29  loss=0.345224
#           test_loss=0.366361  Precision=0.896 Recall=0.767 F1=0.827
# epoch 30  loss=0.334494
#           test_loss=0.336635  Precision=0.861 Recall=0.815 F1=0.837
# epoch 31  loss=0.328584
#           test_loss=0.341625  Precision=0.862 Recall=0.820 F1=0.840
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.328584)
# epoch 32  loss=0.331027
#           test_loss=0.340895  Precision=0.887 Recall=0.790 F1=0.836
# epoch 33  loss=0.314381
#           test_loss=0.338123  Precision=0.847 Recall=0.842 F1=0.844
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.314381)
# epoch 34  loss=0.317299
#           test_loss=0.318850  Precision=0.902 Recall=0.791 F1=0.843
# epoch 35  loss=0.320841
#           test_loss=0.333554  Precision=0.847 Recall=0.811 F1=0.829
# epoch 36  loss=0.317038
#           test_loss=0.333295  Precision=0.824 Recall=0.834 F1=0.829
# epoch 37  loss=0.315672
#           test_loss=0.330818  Precision=0.881 Recall=0.811 F1=0.845
# epoch 38  loss=0.314418
#           test_loss=0.349945  Precision=0.814 Recall=0.830 F1=0.822
# epoch 39  loss=0.318968
#           test_loss=0.315501  Precision=0.885 Recall=0.817 F1=0.850
# epoch 40  loss=0.314254
#           test_loss=0.331615  Precision=0.844 Recall=0.834 F1=0.839
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.314254)
# epoch 41  loss=0.310941
#           test_loss=0.325427  Precision=0.856 Recall=0.828 F1=0.842
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.310941)
# epoch 42  loss=0.310913
#           test_loss=0.318267  Precision=0.879 Recall=0.809 F1=0.843
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.310913)
# epoch 43  loss=0.307068
#           test_loss=0.329339  Precision=0.874 Recall=0.823 F1=0.847
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.307068)
# epoch 44  loss=0.311273
#           test_loss=0.338215  Precision=0.885 Recall=0.808 F1=0.845
# epoch 45  loss=0.309651
#           test_loss=0.338609  Precision=0.863 Recall=0.797 F1=0.829
# epoch 46  loss=0.311971
#           test_loss=0.323304  Precision=0.874 Recall=0.828 F1=0.851
# epoch 47  loss=0.308167
#           test_loss=0.338635  Precision=0.849 Recall=0.804 F1=0.826
# epoch 48  loss=0.308633
#           test_loss=0.319974  Precision=0.887 Recall=0.819 F1=0.852
# epoch 49  loss=0.303630
#           test_loss=0.336457  Precision=0.842 Recall=0.827 F1=0.835
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.303630)
# epoch 50  loss=0.314449
#           test_loss=0.312054  Precision=0.898 Recall=0.813 F1=0.854
# epoch 51  loss=0.307966
#           test_loss=0.320203  Precision=0.873 Recall=0.836 F1=0.855
# epoch 52  loss=0.309527
#           test_loss=0.302042  Precision=0.881 Recall=0.831 F1=0.855
# epoch 53  loss=0.302301
#           test_loss=0.312660  Precision=0.862 Recall=0.827 F1=0.844
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.302301)
# epoch 54  loss=0.304839
#           test_loss=0.326421  Precision=0.884 Recall=0.803 F1=0.842
# epoch 55  loss=0.301603
#           test_loss=0.310725  Precision=0.885 Recall=0.825 F1=0.854
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.301603)
# epoch 56  loss=0.299796
#           test_loss=0.309231  Precision=0.884 Recall=0.811 F1=0.846
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.299796)
# epoch 57  loss=0.299687
#           test_loss=0.313959  Precision=0.888 Recall=0.817 F1=0.851
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.299687)
# epoch 58  loss=0.303158
#           test_loss=0.312636  Precision=0.844 Recall=0.851 F1=0.848
# epoch 59  loss=0.301205
#           test_loss=0.315473  Precision=0.882 Recall=0.826 F1=0.853
# epoch 60  loss=0.299085
#           test_loss=0.322506  Precision=0.877 Recall=0.838 F1=0.857
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.299085)
# epoch 61  loss=0.298631
#           test_loss=0.330586  Precision=0.862 Recall=0.818 F1=0.840
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.298631)
# epoch 62  loss=0.298775
#           test_loss=0.326658  Precision=0.824 Recall=0.842 F1=0.833
# epoch 63  loss=0.304531
#           test_loss=0.307095  Precision=0.866 Recall=0.837 F1=0.851
# epoch 64  loss=0.298227
#           test_loss=0.320344  Precision=0.860 Recall=0.845 F1=0.852
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.298227)
# epoch 65  loss=0.301605
#           test_loss=0.313189  Precision=0.882 Recall=0.826 F1=0.853
# epoch 66  loss=0.302568
#           test_loss=0.325493  Precision=0.882 Recall=0.813 F1=0.846
# epoch 67  loss=0.309962
#           test_loss=0.321047  Precision=0.863 Recall=0.847 F1=0.855
# epoch 68  loss=0.303453
#           test_loss=0.306586  Precision=0.888 Recall=0.816 F1=0.851
# epoch 69  loss=0.299000
#           test_loss=0.302240  Precision=0.865 Recall=0.823 F1=0.844
# epoch 70  loss=0.295170
#           test_loss=0.303948  Precision=0.881 Recall=0.828 F1=0.853
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.295170)
# epoch 71  loss=0.294712
#           test_loss=0.303787  Precision=0.877 Recall=0.830 F1=0.853
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.294712)
# epoch 72  loss=0.296581
#           test_loss=0.312227  Precision=0.883 Recall=0.801 F1=0.840
# epoch 73  loss=0.296035
#           test_loss=0.319868  Precision=0.868 Recall=0.811 F1=0.838
# epoch 74  loss=0.295328
#           test_loss=0.312621  Precision=0.891 Recall=0.827 F1=0.858
# epoch 75  loss=0.295954
#           test_loss=0.309369  Precision=0.856 Recall=0.843 F1=0.849
# epoch 76  loss=0.294703
#           test_loss=0.310691  Precision=0.898 Recall=0.817 F1=0.856
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.294703)
# epoch 77  loss=0.293165
#           test_loss=0.329500  Precision=0.895 Recall=0.816 F1=0.854
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.293165)
# epoch 78  loss=0.291657
#           test_loss=0.307020  Precision=0.860 Recall=0.836 F1=0.848
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.291657)
# epoch 79  loss=0.297658
#           test_loss=0.324000  Precision=0.862 Recall=0.821 F1=0.841
# epoch 80  loss=0.298164
#           test_loss=0.343113  Precision=0.850 Recall=0.813 F1=0.831
# epoch 81  loss=0.305872
#           test_loss=0.315265  Precision=0.849 Recall=0.825 F1=0.837
# epoch 82  loss=0.294056
#           test_loss=0.309165  Precision=0.884 Recall=0.818 F1=0.850
# epoch 83  loss=0.292580
#           test_loss=0.306899  Precision=0.837 Recall=0.844 F1=0.840
# epoch 84  loss=0.290900
#           test_loss=0.315949  Precision=0.856 Recall=0.834 F1=0.845
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.290900)
# epoch 85  loss=0.290869
#           test_loss=0.309474  Precision=0.856 Recall=0.836 F1=0.846
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.290869)
# epoch 86  loss=0.291903
#           test_loss=0.319287  Precision=0.875 Recall=0.819 F1=0.846
# epoch 87  loss=0.289184
#           test_loss=0.299951  Precision=0.879 Recall=0.808 F1=0.842
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.289184)
# epoch 88  loss=0.289971
#           test_loss=0.300334  Precision=0.874 Recall=0.840 F1=0.857
# epoch 89  loss=0.288842
#           test_loss=0.291053  Precision=0.875 Recall=0.833 F1=0.853
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.288842)
# epoch 90  loss=0.285581
#           test_loss=0.302871  Precision=0.868 Recall=0.835 F1=0.851
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.285581)
# epoch 91  loss=0.289610
#           test_loss=0.307316  Precision=0.866 Recall=0.821 F1=0.843
# epoch 92  loss=0.289787
#           test_loss=0.302930  Precision=0.882 Recall=0.836 F1=0.858
# epoch 93  loss=0.288017
#           test_loss=0.287636  Precision=0.891 Recall=0.829 F1=0.859
# epoch 94  loss=0.288080
#           test_loss=0.298342  Precision=0.860 Recall=0.853 F1=0.856
# epoch 95  loss=0.287123
#           test_loss=0.300777  Precision=0.879 Recall=0.819 F1=0.848
# epoch 96  loss=0.285911
#           test_loss=0.309032  Precision=0.897 Recall=0.811 F1=0.852
# epoch 97  loss=0.282837
#           test_loss=0.308600  Precision=0.874 Recall=0.825 F1=0.849
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.282837)
# epoch 98  loss=0.289714
#           test_loss=0.311301  Precision=0.855 Recall=0.849 F1=0.852
# epoch 99  loss=0.294241
#           test_loss=0.300134  Precision=0.878 Recall=0.832 F1=0.854
# epoch 100  loss=0.289187
#           test_loss=0.310822  Precision=0.847 Recall=0.835 F1=0.841
# epoch 101  loss=0.285381
#           test_loss=0.320150  Precision=0.876 Recall=0.817 F1=0.846
# epoch 102  loss=0.288139
#           test_loss=0.312525  Precision=0.890 Recall=0.822 F1=0.855
# epoch 103  loss=0.289452
#           test_loss=0.298346  Precision=0.853 Recall=0.840 F1=0.847
# epoch 104  loss=0.292679
#           test_loss=0.299302  Precision=0.895 Recall=0.813 F1=0.852
# epoch 105  loss=0.285851
#           test_loss=0.302875  Precision=0.864 Recall=0.839 F1=0.852
# epoch 106  loss=0.285349
#           test_loss=0.299905  Precision=0.900 Recall=0.815 F1=0.855
# epoch 107  loss=0.284925
#           test_loss=0.320575  Precision=0.878 Recall=0.805 F1=0.840
# epoch 108  loss=0.291211
#           test_loss=0.305729  Precision=0.876 Recall=0.838 F1=0.857
# epoch 109  loss=0.286334
#           test_loss=0.308916  Precision=0.918 Recall=0.800 F1=0.855
# epoch 110  loss=0.286322
#           test_loss=0.299906  Precision=0.873 Recall=0.845 F1=0.859
# epoch 111  loss=0.294200
#           test_loss=0.297852  Precision=0.897 Recall=0.806 F1=0.849
# epoch 112  loss=0.284189
#           test_loss=0.309201  Precision=0.871 Recall=0.833 F1=0.852
# epoch 113  loss=0.285694
#           test_loss=0.316529  Precision=0.881 Recall=0.823 F1=0.851
# epoch 114  loss=0.288162
#           test_loss=0.321695  Precision=0.860 Recall=0.796 F1=0.827
# epoch 115  loss=0.293924
#           test_loss=0.301502  Precision=0.885 Recall=0.842 F1=0.863
# epoch 116  loss=0.284202
#           test_loss=0.303851  Precision=0.865 Recall=0.821 F1=0.842
# epoch 117  loss=0.289116
#           test_loss=0.296926  Precision=0.890 Recall=0.842 F1=0.865
# epoch 118  loss=0.288579
#           test_loss=0.309895  Precision=0.856 Recall=0.823 F1=0.839
# epoch 119  loss=0.284583
#           test_loss=0.295302  Precision=0.883 Recall=0.828 F1=0.855
# epoch 120  loss=0.286599
#           test_loss=0.317330  Precision=0.853 Recall=0.836 F1=0.844
# epoch 121  loss=0.283603
#           test_loss=0.310971  Precision=0.871 Recall=0.825 F1=0.848
# epoch 122  loss=0.282778
#           test_loss=0.290476  Precision=0.867 Recall=0.862 F1=0.864
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.282778)
# epoch 123  loss=0.285320
#           test_loss=0.315564  Precision=0.880 Recall=0.813 F1=0.845
# epoch 124  loss=0.277601
#           test_loss=0.316909  Precision=0.874 Recall=0.821 F1=0.847
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.277601)
# epoch 125  loss=0.284161
#           test_loss=0.301353  Precision=0.848 Recall=0.834 F1=0.841
# epoch 126  loss=0.280994
#           test_loss=0.301285  Precision=0.903 Recall=0.821 F1=0.860
# epoch 127  loss=0.280269
#           test_loss=0.304642  Precision=0.862 Recall=0.825 F1=0.843
# epoch 128  loss=0.282354
#           test_loss=0.299983  Precision=0.876 Recall=0.832 F1=0.853
# epoch 129  loss=0.285527
#           test_loss=0.298255  Precision=0.876 Recall=0.829 F1=0.852
# epoch 130  loss=0.281091
#           test_loss=0.295112  Precision=0.863 Recall=0.847 F1=0.855
# epoch 131  loss=0.284696
#           test_loss=0.285249  Precision=0.895 Recall=0.831 F1=0.862
# epoch 132  loss=0.287385
#           test_loss=0.306764  Precision=0.850 Recall=0.834 F1=0.842
# epoch 133  loss=0.284835
#           test_loss=0.287904  Precision=0.857 Recall=0.863 F1=0.860
# epoch 134  loss=0.277111
#           test_loss=0.303321  Precision=0.887 Recall=0.832 F1=0.858
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.277111)
# epoch 135  loss=0.282059
#           test_loss=0.294348  Precision=0.901 Recall=0.829 F1=0.863
# epoch 136  loss=0.279879
#           test_loss=0.291433  Precision=0.875 Recall=0.834 F1=0.854
# epoch 137  loss=0.280852
#           test_loss=0.298572  Precision=0.893 Recall=0.801 F1=0.844
# epoch 138  loss=0.283312
#           test_loss=0.305761  Precision=0.867 Recall=0.838 F1=0.852
# epoch 139  loss=0.284126
#           test_loss=0.290578  Precision=0.883 Recall=0.840 F1=0.861
# epoch 140  loss=0.281852
#           test_loss=0.305180  Precision=0.909 Recall=0.774 F1=0.836
# epoch 141  loss=0.282537
#           test_loss=0.310007  Precision=0.860 Recall=0.850 F1=0.855
# epoch 142  loss=0.287119
#           test_loss=0.304001  Precision=0.892 Recall=0.791 F1=0.838
# epoch 143  loss=0.281992
#           test_loss=0.300466  Precision=0.883 Recall=0.842 F1=0.862
# epoch 144  loss=0.284654
#           test_loss=0.314693  Precision=0.881 Recall=0.810 F1=0.844
# epoch 145  loss=0.279481
#           test_loss=0.296712  Precision=0.889 Recall=0.829 F1=0.858
# epoch 146  loss=0.283116
#           test_loss=0.320990  Precision=0.887 Recall=0.812 F1=0.848
# epoch 147  loss=0.285701
#           test_loss=0.314355  Precision=0.844 Recall=0.867 F1=0.856
# epoch 148  loss=0.279120
#           test_loss=0.302686  Precision=0.894 Recall=0.816 F1=0.853
# epoch 149  loss=0.277243
#           test_loss=0.300834  Precision=0.876 Recall=0.817 F1=0.846
# epoch 150  loss=0.276111
#           test_loss=0.300297  Precision=0.855 Recall=0.854 F1=0.855
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.276111)
# epoch 151  loss=0.280244
#           test_loss=0.287919  Precision=0.906 Recall=0.809 F1=0.855
# epoch 152  loss=0.280395
#           test_loss=0.301931  Precision=0.868 Recall=0.830 F1=0.849
# epoch 153  loss=0.281545
#           test_loss=0.294269  Precision=0.896 Recall=0.814 F1=0.853
# epoch 154  loss=0.280096
#           test_loss=0.293031  Precision=0.886 Recall=0.821 F1=0.853
# epoch 155  loss=0.280563
#           test_loss=0.307710  Precision=0.891 Recall=0.789 F1=0.837
# epoch 156  loss=0.276762
#           test_loss=0.296003  Precision=0.877 Recall=0.837 F1=0.856
# epoch 157  loss=0.275200
#           test_loss=0.294029  Precision=0.880 Recall=0.826 F1=0.852
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.275200)
# epoch 158  loss=0.275426
#           test_loss=0.299272  Precision=0.860 Recall=0.839 F1=0.849
# epoch 159  loss=0.278121
#           test_loss=0.302355  Precision=0.892 Recall=0.797 F1=0.841
# epoch 160  loss=0.276399
#           test_loss=0.302239  Precision=0.856 Recall=0.838 F1=0.847
# epoch 161  loss=0.280861
#           test_loss=0.294523  Precision=0.869 Recall=0.828 F1=0.848
# epoch 162  loss=0.278531
#           test_loss=0.290282  Precision=0.886 Recall=0.824 F1=0.854
# epoch 163  loss=0.281757
#           test_loss=0.302854  Precision=0.853 Recall=0.842 F1=0.848
# epoch 164  loss=0.275207
#           test_loss=0.311183  Precision=0.904 Recall=0.783 F1=0.839
# epoch 165  loss=0.275766
#           test_loss=0.302614  Precision=0.859 Recall=0.825 F1=0.842
# epoch 166  loss=0.283026
#           test_loss=0.285565  Precision=0.893 Recall=0.827 F1=0.859
# epoch 167  loss=0.275084
#           test_loss=0.303731  Precision=0.858 Recall=0.831 F1=0.844
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.275084)
# epoch 168  loss=0.271483
#           test_loss=0.306041  Precision=0.874 Recall=0.818 F1=0.845
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.271483)
# epoch 169  loss=0.279376
#           test_loss=0.302553  Precision=0.894 Recall=0.814 F1=0.852
# epoch 170  loss=0.281177
#           test_loss=0.310364  Precision=0.848 Recall=0.846 F1=0.847
# epoch 171  loss=0.278080
#           test_loss=0.318577  Precision=0.903 Recall=0.775 F1=0.834
# epoch 172  loss=0.279637
#           test_loss=0.300372  Precision=0.874 Recall=0.826 F1=0.849
# epoch 173  loss=0.278153
#           test_loss=0.276923  Precision=0.876 Recall=0.833 F1=0.854
# epoch 174  loss=0.278796
#           test_loss=0.289311  Precision=0.858 Recall=0.863 F1=0.860
# epoch 175  loss=0.277408
#           test_loss=0.314095  Precision=0.877 Recall=0.823 F1=0.849
# epoch 176  loss=0.280273
#           test_loss=0.311204  Precision=0.864 Recall=0.821 F1=0.842
# epoch 177  loss=0.282867
#           test_loss=0.302013  Precision=0.883 Recall=0.812 F1=0.846
# epoch 178  loss=0.278728
#           test_loss=0.298925  Precision=0.869 Recall=0.829 F1=0.849
# epoch 179  loss=0.276587
#           test_loss=0.320655  Precision=0.876 Recall=0.800 F1=0.836
# epoch 180  loss=0.274594
#           test_loss=0.281117  Precision=0.867 Recall=0.840 F1=0.853
# epoch 181  loss=0.275201
#           test_loss=0.298563  Precision=0.905 Recall=0.802 F1=0.850
# epoch 182  loss=0.273545
#           test_loss=0.284927  Precision=0.890 Recall=0.834 F1=0.861
# epoch 183  loss=0.271370
#           test_loss=0.307709  Precision=0.885 Recall=0.784 F1=0.832
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.271370)
# epoch 184  loss=0.271544
#           test_loss=0.301835  Precision=0.882 Recall=0.822 F1=0.851
# epoch 185  loss=0.269818
#           test_loss=0.304570  Precision=0.875 Recall=0.819 F1=0.846
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.269818)
# epoch 186  loss=0.270578
#           test_loss=0.304220  Precision=0.872 Recall=0.821 F1=0.846
# epoch 187  loss=0.269993
#           test_loss=0.295745  Precision=0.864 Recall=0.846 F1=0.855
# epoch 188  loss=0.275338
#           test_loss=0.315350  Precision=0.906 Recall=0.794 F1=0.846
# epoch 189  loss=0.280293
#           test_loss=0.281651  Precision=0.852 Recall=0.854 F1=0.853
# epoch 190  loss=0.271491
#           test_loss=0.296043  Precision=0.909 Recall=0.807 F1=0.855
# epoch 191  loss=0.275158
#           test_loss=0.300937  Precision=0.865 Recall=0.843 F1=0.854
# epoch 192  loss=0.277536
#           test_loss=0.282192  Precision=0.891 Recall=0.818 F1=0.853
# epoch 193  loss=0.278819
#           test_loss=0.294611  Precision=0.862 Recall=0.865 F1=0.863
# epoch 194  loss=0.278826
#           test_loss=0.315511  Precision=0.885 Recall=0.806 F1=0.844
# epoch 195  loss=0.277041
#           test_loss=0.289506  Precision=0.870 Recall=0.834 F1=0.852
# epoch 196  loss=0.273955
#           test_loss=0.286611  Precision=0.900 Recall=0.833 F1=0.866
# epoch 197  loss=0.275391
#           test_loss=0.289878  Precision=0.893 Recall=0.827 F1=0.859
# epoch 198  loss=0.274452
#           test_loss=0.295078  Precision=0.853 Recall=0.830 F1=0.842
# epoch 199  loss=0.273034
#           test_loss=0.292398  Precision=0.877 Recall=0.843 F1=0.860
# epoch 200  loss=0.269427
#           test_loss=0.291056  Precision=0.880 Recall=0.854 F1=0.867
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.269427)
# epoch 201  loss=0.275594
#           test_loss=0.309361  Precision=0.874 Recall=0.821 F1=0.847
# epoch 202  loss=0.266792
#           test_loss=0.294499  Precision=0.872 Recall=0.819 F1=0.845
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.266792)
# epoch 203  loss=0.275635
#           test_loss=0.304834  Precision=0.862 Recall=0.841 F1=0.851
# epoch 204  loss=0.274572
#           test_loss=0.293753  Precision=0.877 Recall=0.846 F1=0.861
# epoch 205  loss=0.277501
#           test_loss=0.296436  Precision=0.887 Recall=0.824 F1=0.854
# epoch 206  loss=0.273372
#           test_loss=0.282889  Precision=0.891 Recall=0.843 F1=0.866
# epoch 207  loss=0.277426
#           test_loss=0.295236  Precision=0.865 Recall=0.828 F1=0.846
# epoch 208  loss=0.285261
#           test_loss=0.288205  Precision=0.889 Recall=0.836 F1=0.862
# epoch 209  loss=0.272273
#           test_loss=0.318582  Precision=0.862 Recall=0.813 F1=0.837
# epoch 210  loss=0.274510
#           test_loss=0.290793  Precision=0.894 Recall=0.822 F1=0.856
# epoch 211  loss=0.274618
#           test_loss=0.291161  Precision=0.897 Recall=0.807 F1=0.849
# epoch 212  loss=0.270631
#           test_loss=0.292343  Precision=0.887 Recall=0.842 F1=0.864
# epoch 213  loss=0.272254
#           test_loss=0.291082  Precision=0.899 Recall=0.820 F1=0.858
# epoch 214  loss=0.270364
#           test_loss=0.291004  Precision=0.876 Recall=0.831 F1=0.853
# epoch 215  loss=0.265739
#           test_loss=0.293788  Precision=0.874 Recall=0.813 F1=0.842
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.265739)
# epoch 216  loss=0.266554
#           test_loss=0.292515  Precision=0.887 Recall=0.833 F1=0.859
# epoch 217  loss=0.269326
#           test_loss=0.296195  Precision=0.892 Recall=0.815 F1=0.852
# epoch 218  loss=0.270227
#           test_loss=0.308929  Precision=0.898 Recall=0.816 F1=0.855
# epoch 219  loss=0.269507
#           test_loss=0.293967  Precision=0.876 Recall=0.847 F1=0.861
# epoch 220  loss=0.275240
#           test_loss=0.276901  Precision=0.893 Recall=0.841 F1=0.866
# epoch 221  loss=0.264938
#           test_loss=0.306450  Precision=0.878 Recall=0.829 F1=0.853
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.264938)
# epoch 222  loss=0.277610
#           test_loss=0.294837  Precision=0.887 Recall=0.808 F1=0.846
# epoch 223  loss=0.271596
#           test_loss=0.291623  Precision=0.869 Recall=0.842 F1=0.856
# epoch 224  loss=0.271093
#           test_loss=0.287127  Precision=0.877 Recall=0.851 F1=0.863
# epoch 225  loss=0.266942
#           test_loss=0.289382  Precision=0.897 Recall=0.819 F1=0.856
# epoch 226  loss=0.279331
#           test_loss=0.280152  Precision=0.880 Recall=0.841 F1=0.860
# epoch 227  loss=0.273247
#           test_loss=0.283862  Precision=0.881 Recall=0.837 F1=0.859
# epoch 228  loss=0.272455
#           test_loss=0.285830  Precision=0.889 Recall=0.831 F1=0.859
# epoch 229  loss=0.272558
#           test_loss=0.279142  Precision=0.874 Recall=0.854 F1=0.864
# epoch 230  loss=0.266458
#           test_loss=0.295397  Precision=0.884 Recall=0.822 F1=0.852
# epoch 231  loss=0.270851
#           test_loss=0.284113  Precision=0.898 Recall=0.814 F1=0.854
# epoch 232  loss=0.273562
#           test_loss=0.282378  Precision=0.870 Recall=0.844 F1=0.856
# epoch 233  loss=0.274172
#           test_loss=0.299250  Precision=0.891 Recall=0.807 F1=0.847
# epoch 234  loss=0.272501
#           test_loss=0.275989  Precision=0.882 Recall=0.852 F1=0.866
# epoch 235  loss=0.274672
#           test_loss=0.288674  Precision=0.921 Recall=0.808 F1=0.861
# epoch 236  loss=0.272010
#           test_loss=0.304083  Precision=0.853 Recall=0.832 F1=0.842
# epoch 237  loss=0.268704
#           test_loss=0.271454  Precision=0.904 Recall=0.814 F1=0.857
# epoch 238  loss=0.267189
#           test_loss=0.278775  Precision=0.873 Recall=0.855 F1=0.864
# epoch 239  loss=0.272451
#           test_loss=0.286379  Precision=0.896 Recall=0.819 F1=0.856
# epoch 240  loss=0.265344
#           test_loss=0.302378  Precision=0.880 Recall=0.826 F1=0.852
# epoch 241  loss=0.274024
#           test_loss=0.292731  Precision=0.904 Recall=0.829 F1=0.865
# epoch 242  loss=0.269646
#           test_loss=0.293866  Precision=0.865 Recall=0.842 F1=0.853
# epoch 243  loss=0.266427
#           test_loss=0.295395  Precision=0.887 Recall=0.838 F1=0.862
# epoch 244  loss=0.275192
#           test_loss=0.291866  Precision=0.877 Recall=0.840 F1=0.858
# epoch 245  loss=0.270295
#           test_loss=0.305561  Precision=0.859 Recall=0.831 F1=0.845
# epoch 246  loss=0.271570
#           test_loss=0.289078  Precision=0.901 Recall=0.800 F1=0.848
# epoch 247  loss=0.267589
#           test_loss=0.279678  Precision=0.885 Recall=0.833 F1=0.858
# epoch 248  loss=0.269408
#           test_loss=0.302691  Precision=0.870 Recall=0.813 F1=0.841
# epoch 249  loss=0.268074
#           test_loss=0.291907  Precision=0.876 Recall=0.841 F1=0.858
# epoch 250  loss=0.266228
#           test_loss=0.285898  Precision=0.889 Recall=0.846 F1=0.867
# epoch 251  loss=0.270274
#           test_loss=0.288808  Precision=0.869 Recall=0.849 F1=0.859
# epoch 252  loss=0.268048
#           test_loss=0.291536  Precision=0.893 Recall=0.820 F1=0.855
# epoch 253  loss=0.265357
#           test_loss=0.286409  Precision=0.879 Recall=0.846 F1=0.862
# epoch 254  loss=0.265284
#           test_loss=0.291920  Precision=0.879 Recall=0.839 F1=0.859
# epoch 255  loss=0.265537
#           test_loss=0.310207  Precision=0.893 Recall=0.817 F1=0.853
# epoch 256  loss=0.266684
#           test_loss=0.295596  Precision=0.879 Recall=0.849 F1=0.864
# epoch 257  loss=0.267417
#           test_loss=0.287788  Precision=0.889 Recall=0.824 F1=0.856
# epoch 258  loss=0.273365
#           test_loss=0.293791  Precision=0.864 Recall=0.842 F1=0.853
# epoch 259  loss=0.278806
#           test_loss=0.280840  Precision=0.910 Recall=0.825 F1=0.866
# epoch 260  loss=0.270459
#           test_loss=0.291414  Precision=0.868 Recall=0.870 F1=0.869
# epoch 261  loss=0.267668
#           test_loss=0.298650  Precision=0.895 Recall=0.816 F1=0.853
# epoch 262  loss=0.266874
#           test_loss=0.281984  Precision=0.882 Recall=0.848 F1=0.865
# epoch 263  loss=0.266748
#           test_loss=0.295451  Precision=0.921 Recall=0.782 F1=0.846
# epoch 264  loss=0.266747
#           test_loss=0.278716  Precision=0.883 Recall=0.856 F1=0.869
# epoch 265  loss=0.267419
#           test_loss=0.280050  Precision=0.878 Recall=0.848 F1=0.863
# epoch 266  loss=0.268558
#           test_loss=0.296920  Precision=0.891 Recall=0.835 F1=0.862
# epoch 267  loss=0.267173
#           test_loss=0.295728  Precision=0.891 Recall=0.819 F1=0.854
# epoch 268  loss=0.264228
#           test_loss=0.318225  Precision=0.889 Recall=0.813 F1=0.849
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.264228)
# epoch 269  loss=0.267509
#           test_loss=0.295273  Precision=0.897 Recall=0.821 F1=0.857
# epoch 270  loss=0.270468
#           test_loss=0.286034  Precision=0.883 Recall=0.831 F1=0.856
# epoch 271  loss=0.266080
#           test_loss=0.298408  Precision=0.916 Recall=0.804 F1=0.856
# epoch 272  loss=0.264946
#           test_loss=0.284278  Precision=0.864 Recall=0.838 F1=0.850
# epoch 273  loss=0.264876
#           test_loss=0.284483  Precision=0.868 Recall=0.851 F1=0.859
# epoch 274  loss=0.264902
#           test_loss=0.277132  Precision=0.885 Recall=0.825 F1=0.854
# epoch 275  loss=0.265846
#           test_loss=0.284064  Precision=0.895 Recall=0.824 F1=0.858
# epoch 276  loss=0.265597
#           test_loss=0.281709  Precision=0.877 Recall=0.843 F1=0.860
# epoch 277  loss=0.262212
#           test_loss=0.299348  Precision=0.887 Recall=0.817 F1=0.851
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.262212)
# epoch 278  loss=0.265497
#           test_loss=0.272142  Precision=0.883 Recall=0.860 F1=0.871
# epoch 279  loss=0.269031
#           test_loss=0.294281  Precision=0.891 Recall=0.836 F1=0.863
# epoch 280  loss=0.266679
#           test_loss=0.283379  Precision=0.867 Recall=0.850 F1=0.858
# epoch 281  loss=0.263035
#           test_loss=0.291664  Precision=0.925 Recall=0.776 F1=0.844
# epoch 282  loss=0.267670
#           test_loss=0.288459  Precision=0.879 Recall=0.838 F1=0.858
# epoch 283  loss=0.267906
#           test_loss=0.294701  Precision=0.896 Recall=0.815 F1=0.853
# epoch 284  loss=0.261113
#           test_loss=0.289636  Precision=0.882 Recall=0.838 F1=0.860
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.261113)
# epoch 285  loss=0.268232
#           test_loss=0.270889  Precision=0.906 Recall=0.838 F1=0.871
# epoch 286  loss=0.265690
#           test_loss=0.281018  Precision=0.904 Recall=0.823 F1=0.862
# epoch 287  loss=0.263974
#           test_loss=0.302441  Precision=0.879 Recall=0.815 F1=0.846
# epoch 288  loss=0.263491
#           test_loss=0.297263  Precision=0.879 Recall=0.800 F1=0.837
# epoch 289  loss=0.265558
#           test_loss=0.296604  Precision=0.881 Recall=0.840 F1=0.860
# epoch 290  loss=0.271359
#           test_loss=0.290322  Precision=0.877 Recall=0.855 F1=0.866
# epoch 291  loss=0.268997
#           test_loss=0.300027  Precision=0.890 Recall=0.800 F1=0.843
# epoch 292  loss=0.264040
#           test_loss=0.287633  Precision=0.889 Recall=0.850 F1=0.869
# epoch 293  loss=0.264539
#           test_loss=0.276455  Precision=0.899 Recall=0.840 F1=0.869
# epoch 294  loss=0.261624
#           test_loss=0.288425  Precision=0.904 Recall=0.835 F1=0.868
# epoch 295  loss=0.270554
#           test_loss=0.293994  Precision=0.920 Recall=0.834 F1=0.875
# epoch 296  loss=0.264766
#           test_loss=0.299857  Precision=0.864 Recall=0.836 F1=0.850
# epoch 297  loss=0.267307
#           test_loss=0.291754  Precision=0.885 Recall=0.838 F1=0.861
# epoch 298  loss=0.263019
#           test_loss=0.281781  Precision=0.890 Recall=0.844 F1=0.867
# epoch 299  loss=0.264159
#           test_loss=0.283585  Precision=0.881 Recall=0.844 F1=0.862
# epoch 300  loss=0.263368
#           test_loss=0.309490  Precision=0.871 Recall=0.823 F1=0.846
# epoch 301  loss=0.263712
#           test_loss=0.291874  Precision=0.893 Recall=0.849 F1=0.870
# epoch 302  loss=0.267751
#           test_loss=0.277055  Precision=0.887 Recall=0.849 F1=0.868
# epoch 303  loss=0.262434
#           test_loss=0.289933  Precision=0.884 Recall=0.854 F1=0.868
# epoch 304  loss=0.259512
#           test_loss=0.294507  Precision=0.906 Recall=0.821 F1=0.862
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.259512)
# epoch 305  loss=0.259352
#           test_loss=0.284969  Precision=0.880 Recall=0.837 F1=0.858
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.259352)
# epoch 306  loss=0.264569
#           test_loss=0.289687  Precision=0.862 Recall=0.838 F1=0.850
# epoch 307  loss=0.260229
#           test_loss=0.275883  Precision=0.876 Recall=0.855 F1=0.865
# epoch 308  loss=0.266457
#           test_loss=0.280464  Precision=0.864 Recall=0.857 F1=0.861
# epoch 309  loss=0.264618
#           test_loss=0.292569  Precision=0.890 Recall=0.807 F1=0.847
# epoch 310  loss=0.258023
#           test_loss=0.286863  Precision=0.901 Recall=0.815 F1=0.856
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.258023)
# epoch 311  loss=0.264499
#           test_loss=0.294719  Precision=0.874 Recall=0.846 F1=0.860
# epoch 312  loss=0.257843
#           test_loss=0.295806  Precision=0.890 Recall=0.810 F1=0.848
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.257843)
# epoch 313  loss=0.263423
#           test_loss=0.275389  Precision=0.914 Recall=0.827 F1=0.868
# epoch 314  loss=0.261671
#           test_loss=0.265067  Precision=0.911 Recall=0.829 F1=0.868
# epoch 315  loss=0.259556
#           test_loss=0.275604  Precision=0.878 Recall=0.832 F1=0.854
# epoch 316  loss=0.260246
#           test_loss=0.290171  Precision=0.875 Recall=0.839 F1=0.856
# epoch 317  loss=0.267250
#           test_loss=0.282217  Precision=0.895 Recall=0.830 F1=0.861
# epoch 318  loss=0.258902
#           test_loss=0.289150  Precision=0.901 Recall=0.837 F1=0.867
# epoch 319  loss=0.260657
#           test_loss=0.282353  Precision=0.899 Recall=0.827 F1=0.861
# epoch 320  loss=0.257808
#           test_loss=0.279025  Precision=0.889 Recall=0.840 F1=0.864
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.257808)
# epoch 321  loss=0.259094
#           test_loss=0.304032  Precision=0.872 Recall=0.816 F1=0.843
# epoch 322  loss=0.265258
#           test_loss=0.285200  Precision=0.870 Recall=0.848 F1=0.859
# epoch 323  loss=0.263896
#           test_loss=0.286500  Precision=0.896 Recall=0.820 F1=0.856
# epoch 324  loss=0.262636
#           test_loss=0.288693  Precision=0.881 Recall=0.833 F1=0.856
# epoch 325  loss=0.264071
#           test_loss=0.295400  Precision=0.872 Recall=0.824 F1=0.847
# epoch 326  loss=0.263671
#           test_loss=0.281838  Precision=0.898 Recall=0.823 F1=0.859
# epoch 327  loss=0.256561
#           test_loss=0.292333  Precision=0.875 Recall=0.828 F1=0.851
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.256561)
# epoch 328  loss=0.261728
#           test_loss=0.299169  Precision=0.896 Recall=0.833 F1=0.863
# epoch 329  loss=0.265275
#           test_loss=0.304093  Precision=0.863 Recall=0.823 F1=0.843
# epoch 330  loss=0.265978
#           test_loss=0.289998  Precision=0.904 Recall=0.781 F1=0.838
# epoch 331  loss=0.255650
#           test_loss=0.290304  Precision=0.870 Recall=0.836 F1=0.853
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.255650)
# epoch 332  loss=0.258053
#           test_loss=0.280580  Precision=0.890 Recall=0.821 F1=0.854
# epoch 333  loss=0.259111
#           test_loss=0.299508  Precision=0.883 Recall=0.812 F1=0.846
# epoch 334  loss=0.264410
#           test_loss=0.270849  Precision=0.915 Recall=0.838 F1=0.875
# epoch 335  loss=0.254897
#           test_loss=0.291769  Precision=0.850 Recall=0.848 F1=0.849
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.254897)
# epoch 336  loss=0.259285
#           test_loss=0.280946  Precision=0.898 Recall=0.833 F1=0.864
# epoch 337  loss=0.259746
#           test_loss=0.298440  Precision=0.859 Recall=0.833 F1=0.846
# epoch 338  loss=0.259299
#           test_loss=0.293007  Precision=0.897 Recall=0.826 F1=0.860
# epoch 339  loss=0.262976
#           test_loss=0.301980  Precision=0.873 Recall=0.809 F1=0.839
# epoch 340  loss=0.255713
#           test_loss=0.285795  Precision=0.892 Recall=0.842 F1=0.867
# epoch 341  loss=0.267888
#           test_loss=0.289155  Precision=0.861 Recall=0.840 F1=0.850
# epoch 342  loss=0.262948
#           test_loss=0.291294  Precision=0.891 Recall=0.835 F1=0.862
# epoch 343  loss=0.264531
#           test_loss=0.270950  Precision=0.905 Recall=0.840 F1=0.871
# epoch 344  loss=0.257933
#           test_loss=0.283057  Precision=0.892 Recall=0.823 F1=0.856
# epoch 345  loss=0.257540
#           test_loss=0.292791  Precision=0.895 Recall=0.819 F1=0.855
# epoch 346  loss=0.262619
#           test_loss=0.292013  Precision=0.842 Recall=0.868 F1=0.855
# epoch 347  loss=0.259997
#           test_loss=0.271267  Precision=0.903 Recall=0.833 F1=0.866
# epoch 348  loss=0.258393
#           test_loss=0.287635  Precision=0.884 Recall=0.838 F1=0.860
# epoch 349  loss=0.254949
#           test_loss=0.273209  Precision=0.911 Recall=0.834 F1=0.871
# epoch 350  loss=0.255633
#           test_loss=0.284759  Precision=0.876 Recall=0.835 F1=0.855
# epoch 351  loss=0.257841
#           test_loss=0.282207  Precision=0.877 Recall=0.834 F1=0.855
# epoch 352  loss=0.260494
#           test_loss=0.307650  Precision=0.880 Recall=0.819 F1=0.848
# epoch 353  loss=0.258917
#           test_loss=0.285294  Precision=0.897 Recall=0.821 F1=0.857
# epoch 354  loss=0.257357
#           test_loss=0.273093  Precision=0.896 Recall=0.834 F1=0.864
# epoch 355  loss=0.255083
#           test_loss=0.275111  Precision=0.901 Recall=0.823 F1=0.860
# epoch 356  loss=0.254467
#           test_loss=0.268922  Precision=0.902 Recall=0.831 F1=0.865
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.254467)
# epoch 357  loss=0.259458
#           test_loss=0.279203  Precision=0.849 Recall=0.867 F1=0.858
# epoch 358  loss=0.254961
#           test_loss=0.277596  Precision=0.920 Recall=0.803 F1=0.858
# epoch 359  loss=0.264720
#           test_loss=0.281537  Precision=0.875 Recall=0.861 F1=0.868
# epoch 360  loss=0.258392
#           test_loss=0.285006  Precision=0.893 Recall=0.830 F1=0.861
# epoch 361  loss=0.257100
#           test_loss=0.289238  Precision=0.875 Recall=0.847 F1=0.861
# epoch 362  loss=0.257442
#           test_loss=0.292018  Precision=0.883 Recall=0.836 F1=0.859
# epoch 363  loss=0.262838
#           test_loss=0.291225  Precision=0.904 Recall=0.822 F1=0.861
# epoch 364  loss=0.259266
#           test_loss=0.291646  Precision=0.867 Recall=0.831 F1=0.848
# epoch 365  loss=0.255643
#           test_loss=0.285413  Precision=0.890 Recall=0.835 F1=0.862
# epoch 366  loss=0.260658
#           test_loss=0.291516  Precision=0.860 Recall=0.850 F1=0.855
# epoch 367  loss=0.260588
#           test_loss=0.282942  Precision=0.914 Recall=0.818 F1=0.863
# epoch 368  loss=0.256932
#           test_loss=0.281301  Precision=0.893 Recall=0.818 F1=0.854
# epoch 369  loss=0.262578
#           test_loss=0.282276  Precision=0.866 Recall=0.847 F1=0.856
# epoch 370  loss=0.256196
#           test_loss=0.274254  Precision=0.904 Recall=0.834 F1=0.868
# epoch 371  loss=0.256659
#           test_loss=0.287617  Precision=0.874 Recall=0.829 F1=0.851
# epoch 372  loss=0.258890
#           test_loss=0.274080  Precision=0.898 Recall=0.837 F1=0.866
# epoch 373  loss=0.257256
#           test_loss=0.291442  Precision=0.870 Recall=0.841 F1=0.855
# epoch 374  loss=0.259863
#           test_loss=0.303270  Precision=0.876 Recall=0.820 F1=0.847
# epoch 375  loss=0.254337
#           test_loss=0.273456  Precision=0.887 Recall=0.840 F1=0.863
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.254337)
# epoch 376  loss=0.261806
#           test_loss=0.275457  Precision=0.870 Recall=0.849 F1=0.859
# epoch 377  loss=0.257098
#           test_loss=0.289434  Precision=0.899 Recall=0.817 F1=0.856
# epoch 378  loss=0.251612
#           test_loss=0.270652  Precision=0.906 Recall=0.848 F1=0.876
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.251612)
# epoch 379  loss=0.256646
#           test_loss=0.281037  Precision=0.889 Recall=0.835 F1=0.861
# epoch 380  loss=0.254182
#           test_loss=0.267581  Precision=0.886 Recall=0.852 F1=0.868
# epoch 381  loss=0.255077
#           test_loss=0.287110  Precision=0.877 Recall=0.829 F1=0.853
# epoch 382  loss=0.254972
#           test_loss=0.283556  Precision=0.909 Recall=0.824 F1=0.864
# epoch 383  loss=0.255141
#           test_loss=0.265656  Precision=0.888 Recall=0.851 F1=0.869
# epoch 384  loss=0.256907
#           test_loss=0.277176  Precision=0.902 Recall=0.823 F1=0.861
# epoch 385  loss=0.258785
#           test_loss=0.287641  Precision=0.884 Recall=0.831 F1=0.857
# epoch 386  loss=0.254687
#           test_loss=0.284232  Precision=0.894 Recall=0.828 F1=0.860
# epoch 387  loss=0.254505
#           test_loss=0.278309  Precision=0.873 Recall=0.861 F1=0.867
# epoch 388  loss=0.256351
#           test_loss=0.255591  Precision=0.892 Recall=0.858 F1=0.875
# epoch 389  loss=0.253858
#           test_loss=0.273692  Precision=0.894 Recall=0.831 F1=0.861
# epoch 390  loss=0.252681
#           test_loss=0.291062  Precision=0.857 Recall=0.874 F1=0.866
# epoch 391  loss=0.256603
#           test_loss=0.279680  Precision=0.886 Recall=0.847 F1=0.866
# epoch 392  loss=0.251387
#           test_loss=0.272103  Precision=0.897 Recall=0.825 F1=0.860
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.251387)
# epoch 393  loss=0.256214
#           test_loss=0.289063  Precision=0.896 Recall=0.835 F1=0.865
# epoch 394  loss=0.248190
#           test_loss=0.257547  Precision=0.926 Recall=0.831 F1=0.876
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.248190)
# epoch 395  loss=0.250710
#           test_loss=0.283952  Precision=0.869 Recall=0.862 F1=0.865
# epoch 396  loss=0.251823
#           test_loss=0.262822  Precision=0.906 Recall=0.833 F1=0.868
# epoch 397  loss=0.252420
#           test_loss=0.276102  Precision=0.864 Recall=0.848 F1=0.856
# epoch 398  loss=0.251792
#           test_loss=0.269982  Precision=0.890 Recall=0.838 F1=0.863
# epoch 399  loss=0.247919
#           test_loss=0.260177  Precision=0.905 Recall=0.856 F1=0.880
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.247919)
# epoch 400  loss=0.255614
#           test_loss=0.275724  Precision=0.869 Recall=0.870 F1=0.870
# epoch 401  loss=0.249140
#           test_loss=0.269585  Precision=0.895 Recall=0.828 F1=0.860
# epoch 402  loss=0.242964
#           test_loss=0.275332  Precision=0.910 Recall=0.836 F1=0.872
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.242964)
# epoch 403  loss=0.246273
#           test_loss=0.290614  Precision=0.859 Recall=0.853 F1=0.856
# epoch 404  loss=0.246370
#           test_loss=0.273808  Precision=0.882 Recall=0.851 F1=0.866
# epoch 405  loss=0.240219
#           test_loss=0.265683  Precision=0.892 Recall=0.866 F1=0.879
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.240219)
# epoch 406  loss=0.242397
#           test_loss=0.270953  Precision=0.893 Recall=0.839 F1=0.865
# epoch 407  loss=0.246760
#           test_loss=0.261611  Precision=0.887 Recall=0.851 F1=0.868
# epoch 408  loss=0.238599
#           test_loss=0.253874  Precision=0.899 Recall=0.858 F1=0.878
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.238599)
# epoch 409  loss=0.241049
#           test_loss=0.261761  Precision=0.894 Recall=0.855 F1=0.874
# epoch 410  loss=0.239921
#           test_loss=0.262251  Precision=0.902 Recall=0.854 F1=0.877
# epoch 411  loss=0.237685
#           test_loss=0.272867  Precision=0.898 Recall=0.862 F1=0.880
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.237685)
# epoch 412  loss=0.244326
#           test_loss=0.278470  Precision=0.891 Recall=0.848 F1=0.869
# epoch 413  loss=0.240342
#           test_loss=0.268520  Precision=0.890 Recall=0.840 F1=0.864
# epoch 414  loss=0.245097
#           test_loss=0.250301  Precision=0.882 Recall=0.877 F1=0.880
# epoch 415  loss=0.235967
#           test_loss=0.253141  Precision=0.894 Recall=0.870 F1=0.882
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.235967)
# epoch 416  loss=0.240136
#           test_loss=0.280737  Precision=0.898 Recall=0.827 F1=0.861
# epoch 417  loss=0.239663
#           test_loss=0.279378  Precision=0.866 Recall=0.841 F1=0.853
# epoch 418  loss=0.236509
#           test_loss=0.281196  Precision=0.927 Recall=0.789 F1=0.853
# epoch 419  loss=0.245964
#           test_loss=0.274190  Precision=0.861 Recall=0.868 F1=0.864
# epoch 420  loss=0.242954
#           test_loss=0.280628  Precision=0.916 Recall=0.808 F1=0.859
# epoch 421  loss=0.244798
#           test_loss=0.264256  Precision=0.904 Recall=0.865 F1=0.884
# epoch 422  loss=0.235983
#           test_loss=0.246916  Precision=0.908 Recall=0.883 F1=0.895
# epoch 423  loss=0.241806
#           test_loss=0.248745  Precision=0.910 Recall=0.880 F1=0.894
# epoch 424  loss=0.235034
#           test_loss=0.255656  Precision=0.917 Recall=0.858 F1=0.886
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.235034)
# epoch 425  loss=0.232092
#           test_loss=0.245229  Precision=0.913 Recall=0.862 F1=0.887
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.232092)
# epoch 426  loss=0.247884
#           test_loss=0.268345  Precision=0.873 Recall=0.886 F1=0.879
# epoch 427  loss=0.240260
#           test_loss=0.269438  Precision=0.915 Recall=0.837 F1=0.874
# epoch 428  loss=0.242371
#           test_loss=0.257305  Precision=0.907 Recall=0.857 F1=0.881
# epoch 429  loss=0.236831
#           test_loss=0.258700  Precision=0.909 Recall=0.876 F1=0.892
# epoch 430  loss=0.238442
#           test_loss=0.253224  Precision=0.896 Recall=0.876 F1=0.886
# epoch 431  loss=0.232124
#           test_loss=0.251835  Precision=0.906 Recall=0.891 F1=0.898
# epoch 432  loss=0.229336
#           test_loss=0.261020  Precision=0.891 Recall=0.869 F1=0.880
#   saved best -> Models/single_voice_tcn_20260301_134903_670487.pt (best=0.229336)
# epoch 433  loss=0.231335
#           test_loss=0.251312  Precision=0.919 Recall=0.849 F1=0.883
# epoch 434  loss=0.231834
#           test_loss=0.244182  Precision=0.876 Recall=0.912 F1=0.893
# epoch 435  loss=0.236623
#           test_loss=0.257850  Precision=0.916 Recall=0.889 F1=0.902
# epoch 436  loss=0.233780
#           test_loss=0.242345  Precision=0.900 Recall=0.892 F1=0.896
# epoch 437  loss=0.229732
#           test_loss=0.255672  Precision=0.920 Recall=0.865 F1=0.891
# ...
#           test_loss=0.284432  Precision=0.917 Recall=0.848 F1=0.881
# epoch 2175  loss=0.167893
#           test_loss=0.255505  Precision=0.921 Recall=0.847 F1=0.882
# epoch 2176  loss=0.163965
#           test_loss=0.248769  Precision=0.905 Recall=0.877 F1=0.891
# epoch 2177  loss=0.173261
#           test_loss=0.290049  Precision=0.897 Recall=0.863 F1=0.880
# epoch 2178  loss=0.170931
#           test_loss=0.257833  Precision=0.881 Recall=0.893 F1=0.887
# epoch 2179  loss=0.173648
#           test_loss=0.270760  Precision=0.922 Recall=0.834 F1=0.876
# epoch 2180  loss=0.171667
#           test_loss=0.261088  Precision=0.907 Recall=0.883 F1=0.895
# epoch 2181  loss=0.172365
#           test_loss=0.265298  Precision=0.894 Recall=0.865 F1=0.879
# epoch 2182  loss=0.166610
#           test_loss=0.247424  Precision=0.919 Recall=0.879 F1=0.899
# epoch 2183  loss=0.171679
#           test_loss=0.270251  Precision=0.928 Recall=0.868 F1=0.897
# epoch 2184  loss=0.171021
#           test_loss=0.266987  Precision=0.889 Recall=0.866 F1=0.877
# epoch 2185  loss=0.169342
#           test_loss=0.256812  Precision=0.922 Recall=0.869 F1=0.894
# epoch 2186  loss=0.170654
#           test_loss=0.257945  Precision=0.915 Recall=0.882 F1=0.898
# epoch 2187  loss=0.171441
#           test_loss=0.274530  Precision=0.872 Recall=0.858 F1=0.864
# epoch 2188  loss=0.166864
#           test_loss=0.265380  Precision=0.899 Recall=0.879 F1=0.889
# epoch 2189  loss=0.169436
#           test_loss=0.257000  Precision=0.906 Recall=0.871 F1=0.888
# epoch 2190  loss=0.165422
#           test_loss=0.280770  Precision=0.899 Recall=0.867 F1=0.883
# epoch 2191  loss=0.167631
#           test_loss=0.260239  Precision=0.920 Recall=0.858 F1=0.888
# epoch 2192  loss=0.172021
#           test_loss=0.263058  Precision=0.908 Recall=0.883 F1=0.895
# epoch 2193  loss=0.179801
#           test_loss=0.262782  Precision=0.904 Recall=0.859 F1=0.881
# epoch 2194  loss=0.171752
#           test_loss=0.282743  Precision=0.897 Recall=0.841 F1=0.868
# epoch 2195  loss=0.176602
#           test_loss=0.269022  Precision=0.917 Recall=0.863 F1=0.889
# epoch 2196  loss=0.168264
#           test_loss=0.270036  Precision=0.905 Recall=0.872 F1=0.889
# epoch 2197  loss=0.169758
#           test_loss=0.259268  Precision=0.901 Recall=0.868 F1=0.884
# epoch 2198  loss=0.170796
#           test_loss=0.280066  Precision=0.907 Recall=0.852 F1=0.879
# epoch 2199  loss=0.168760
#           test_loss=0.284689  Precision=0.909 Recall=0.849 F1=0.878
# epoch 2200  loss=0.170039
#           test_loss=0.280627  Precision=0.914 Recall=0.858 F1=0.885
# epoch 2201  loss=0.174929
#           test_loss=0.279807  Precision=0.882 Recall=0.877 F1=0.879
# epoch 2202  loss=0.169598
#           test_loss=0.262550  Precision=0.904 Recall=0.881 F1=0.893
# epoch 2203  loss=0.171262
#           test_loss=0.275339  Precision=0.905 Recall=0.848 F1=0.876
# epoch 2204  loss=0.166126
#           test_loss=0.267193  Precision=0.927 Recall=0.872 F1=0.899
# epoch 2205  loss=0.174762
#           test_loss=0.277264  Precision=0.932 Recall=0.843 F1=0.886
# epoch 2206  loss=0.170040
#           test_loss=0.273581  Precision=0.915 Recall=0.845 F1=0.879
# epoch 2207  loss=0.166623
#           test_loss=0.267680  Precision=0.924 Recall=0.851 F1=0.886
# epoch 2208  loss=0.174232
#           test_loss=0.277320  Precision=0.904 Recall=0.862 F1=0.882
# epoch 2209  loss=0.169620
#           test_loss=0.260729  Precision=0.898 Recall=0.881 F1=0.889
# epoch 2210  loss=0.172304
#           test_loss=0.282679  Precision=0.901 Recall=0.855 F1=0.878
# epoch 2211  loss=0.172270
#           test_loss=0.288537  Precision=0.908 Recall=0.860 F1=0.883
# epoch 2212  loss=0.169119
#           test_loss=0.279579  Precision=0.897 Recall=0.838 F1=0.866
# epoch 2213  loss=0.169017
#           test_loss=0.240415  Precision=0.914 Recall=0.885 F1=0.899
# epoch 2214  loss=0.165126
#           test_loss=0.266035  Precision=0.904 Recall=0.870 F1=0.887
# epoch 2215  loss=0.168596
#           test_loss=0.289597  Precision=0.913 Recall=0.869 F1=0.891
# epoch 2216  loss=0.167917
#           test_loss=0.284337  Precision=0.912 Recall=0.832 F1=0.870
# epoch 2217  loss=0.169651
#           test_loss=0.269112  Precision=0.912 Recall=0.872 F1=0.892
# epoch 2218  loss=0.174060
#           test_loss=0.280151  Precision=0.898 Recall=0.893 F1=0.896
# epoch 2219  loss=0.167296
#           test_loss=0.260006  Precision=0.892 Recall=0.884 F1=0.888
# epoch 2220  loss=0.174991
#           test_loss=0.278843  Precision=0.900 Recall=0.860 F1=0.879
# epoch 2221  loss=0.166999
#           test_loss=0.256127  Precision=0.888 Recall=0.884 F1=0.886
# epoch 2222  loss=0.168793
#           test_loss=0.284650  Precision=0.904 Recall=0.867 F1=0.885
# epoch 2223  loss=0.173319
#           test_loss=0.270035  Precision=0.888 Recall=0.879 F1=0.883
# epoch 2224  loss=0.168779
#           test_loss=0.274561  Precision=0.896 Recall=0.871 F1=0.883
# epoch 2225  loss=0.169286
#           test_loss=0.254364  Precision=0.923 Recall=0.875 F1=0.899
# epoch 2226  loss=0.171344
#           test_loss=0.263868  Precision=0.906 Recall=0.866 F1=0.886
# epoch 2227  loss=0.173556
#           test_loss=0.284443  Precision=0.898 Recall=0.853 F1=0.875
# epoch 2228  loss=0.166024
#           test_loss=0.285381  Precision=0.897 Recall=0.844 F1=0.870
# epoch 2229  loss=0.163124
#           test_loss=0.273475  Precision=0.914 Recall=0.845 F1=0.878
# epoch 2230  loss=0.165368
#           test_loss=0.264477  Precision=0.914 Recall=0.860 F1=0.886
# epoch 2231  loss=0.168063
#           test_loss=0.273428  Precision=0.916 Recall=0.860 F1=0.887
# epoch 2232  loss=0.168500
#           test_loss=0.283198  Precision=0.908 Recall=0.860 F1=0.883
# epoch 2233  loss=0.172688
#           test_loss=0.272025  Precision=0.908 Recall=0.874 F1=0.891
# epoch 2234  loss=0.164513
#           test_loss=0.291774  Precision=0.908 Recall=0.829 F1=0.866
# epoch 2235  loss=0.167140
#           test_loss=0.270297  Precision=0.916 Recall=0.865 F1=0.890
# epoch 2236  loss=0.168944
#           test_loss=0.264845  Precision=0.914 Recall=0.868 F1=0.890
# epoch 2237  loss=0.168760
#           test_loss=0.280253  Precision=0.913 Recall=0.837 F1=0.873
# epoch 2238  loss=0.182045
#           test_loss=0.280539  Precision=0.884 Recall=0.864 F1=0.874
# epoch 2239  loss=0.168309
#           test_loss=0.263799  Precision=0.903 Recall=0.854 F1=0.878
# epoch 2240  loss=0.170607
#           test_loss=0.272163  Precision=0.907 Recall=0.880 F1=0.894
# epoch 2241  loss=0.173739
#           test_loss=0.247995  Precision=0.929 Recall=0.875 F1=0.901
# epoch 2242  loss=0.169118
#           test_loss=0.261835  Precision=0.919 Recall=0.867 F1=0.892
# epoch 2243  loss=0.165854
#           test_loss=0.248528  Precision=0.907 Recall=0.874 F1=0.890
# epoch 2244  loss=0.168038
#           test_loss=0.279778  Precision=0.915 Recall=0.849 F1=0.881
# epoch 2245  loss=0.166284
#           test_loss=0.255367  Precision=0.900 Recall=0.865 F1=0.882
# epoch 2246  loss=0.171058
#           test_loss=0.286969  Precision=0.886 Recall=0.863 F1=0.874
# epoch 2247  loss=0.168452
#           test_loss=0.269435  Precision=0.895 Recall=0.887 F1=0.891
# epoch 2248  loss=0.167465
#           test_loss=0.277072  Precision=0.921 Recall=0.859 F1=0.889
# epoch 2249  loss=0.167408
#           test_loss=0.267646  Precision=0.906 Recall=0.855 F1=0.880
# epoch 2250  loss=0.167087
#           test_loss=0.253689  Precision=0.917 Recall=0.860 F1=0.888
# epoch 2251  loss=0.172727
#           test_loss=0.241681  Precision=0.905 Recall=0.892 F1=0.898
# epoch 2252  loss=0.170124
#           test_loss=0.287509  Precision=0.893 Recall=0.838 F1=0.865
# epoch 2253  loss=0.166810
#           test_loss=0.265347  Precision=0.921 Recall=0.854 F1=0.886
# epoch 2254  loss=0.168162
#           test_loss=0.273933  Precision=0.902 Recall=0.873 F1=0.887
# epoch 2255  loss=0.162631
#           test_loss=0.285380  Precision=0.895 Recall=0.850 F1=0.872
# epoch 2256  loss=0.170232
#           test_loss=0.258021  Precision=0.900 Recall=0.876 F1=0.888
# epoch 2257  loss=0.169902
#           test_loss=0.285506  Precision=0.883 Recall=0.870 F1=0.876
# epoch 2258  loss=0.168456
#           test_loss=0.264500  Precision=0.908 Recall=0.856 F1=0.881
# epoch 2259  loss=0.164970
#           test_loss=0.267681  Precision=0.913 Recall=0.869 F1=0.891
# epoch 2260  loss=0.168933
#           test_loss=0.286086  Precision=0.898 Recall=0.866 F1=0.882
# epoch 2261  loss=0.170134
#           test_loss=0.270457  Precision=0.911 Recall=0.877 F1=0.893
# epoch 2262  loss=0.168014
#           test_loss=0.290165  Precision=0.925 Recall=0.824 F1=0.872
# epoch 2263  loss=0.165421
#           test_loss=0.289306  Precision=0.911 Recall=0.819 F1=0.862
# epoch 2264  loss=0.170731
#           test_loss=0.279968  Precision=0.904 Recall=0.876 F1=0.890
# epoch 2265  loss=0.171581
#           test_loss=0.260739  Precision=0.915 Recall=0.850 F1=0.881
# epoch 2266  loss=0.174565
#           test_loss=0.287652  Precision=0.917 Recall=0.841 F1=0.877
# epoch 2267  loss=0.167259
#           test_loss=0.277388  Precision=0.898 Recall=0.877 F1=0.887
# epoch 2268  loss=0.169789
#           test_loss=0.285796  Precision=0.897 Recall=0.872 F1=0.884
# epoch 2269  loss=0.176133
#           test_loss=0.271404  Precision=0.907 Recall=0.863 F1=0.884
# epoch 2270  loss=0.171456
#           test_loss=0.289909  Precision=0.881 Recall=0.852 F1=0.866
# epoch 2271  loss=0.169381
#           test_loss=0.278861  Precision=0.895 Recall=0.871 F1=0.883
# epoch 2272  loss=0.167456
#           test_loss=0.279680  Precision=0.877 Recall=0.869 F1=0.873
# epoch 2273  loss=0.167626
#           test_loss=0.277721  Precision=0.911 Recall=0.867 F1=0.889
# epoch 2274  loss=0.165758
#           test_loss=0.256225  Precision=0.910 Recall=0.866 F1=0.888
# epoch 2275  loss=0.170855
#           test_loss=0.262265  Precision=0.912 Recall=0.860 F1=0.885
# epoch 2276  loss=0.164664
#           test_loss=0.276731  Precision=0.905 Recall=0.859 F1=0.881
# epoch 2277  loss=0.167777
#           test_loss=0.272437  Precision=0.899 Recall=0.850 F1=0.874
# epoch 2278  loss=0.165264
#           test_loss=0.271567  Precision=0.879 Recall=0.872 F1=0.876
# epoch 2279  loss=0.166346
#           test_loss=0.262896  Precision=0.910 Recall=0.886 F1=0.898
# epoch 2280  loss=0.162751
#           test_loss=0.268975  Precision=0.923 Recall=0.850 F1=0.885
# epoch 2281  loss=0.171332
#           test_loss=0.276923  Precision=0.886 Recall=0.876 F1=0.881
# epoch 2282  loss=0.170347
#           test_loss=0.255859  Precision=0.903 Recall=0.869 F1=0.886
# epoch 2283  loss=0.169072
#           test_loss=0.279414  Precision=0.907 Recall=0.855 F1=0.881
# epoch 2284  loss=0.163265
#           test_loss=0.255159  Precision=0.906 Recall=0.892 F1=0.899
# epoch 2285  loss=0.165190
#           test_loss=0.283797  Precision=0.924 Recall=0.850 F1=0.885
# epoch 2286  loss=0.165579
#           test_loss=0.287094  Precision=0.905 Recall=0.849 F1=0.876
# epoch 2287  loss=0.162649
#           test_loss=0.259811  Precision=0.891 Recall=0.876 F1=0.883
# epoch 2288  loss=0.171759
#           test_loss=0.280863  Precision=0.902 Recall=0.875 F1=0.888
# epoch 2289  loss=0.171904
#           test_loss=0.261159  Precision=0.908 Recall=0.867 F1=0.887
# epoch 2290  loss=0.163781
#           test_loss=0.276985  Precision=0.900 Recall=0.853 F1=0.876
# epoch 2291  loss=0.169092
#           test_loss=0.270152  Precision=0.907 Recall=0.872 F1=0.889
# epoch 2292  loss=0.165717
#           test_loss=0.263414  Precision=0.904 Recall=0.885 F1=0.895
# epoch 2293  loss=0.173282
#           test_loss=0.276979  Precision=0.924 Recall=0.841 F1=0.881
# epoch 2294  loss=0.176259
#           test_loss=0.276241  Precision=0.892 Recall=0.887 F1=0.890
# epoch 2295  loss=0.173878
#           test_loss=0.259122  Precision=0.904 Recall=0.871 F1=0.887
# epoch 2296  loss=0.167486
#           test_loss=0.263945  Precision=0.907 Recall=0.871 F1=0.888
# epoch 2297  loss=0.175026
#           test_loss=0.258778  Precision=0.909 Recall=0.878 F1=0.893
# epoch 2298  loss=0.172667
#           test_loss=0.270226  Precision=0.905 Recall=0.874 F1=0.889
# epoch 2299  loss=0.176128
#           test_loss=0.251088  Precision=0.915 Recall=0.875 F1=0.895
# epoch 2300  loss=0.172738
#           test_loss=0.284564  Precision=0.916 Recall=0.849 F1=0.881
# epoch 2301  loss=0.170088
#           test_loss=0.283316  Precision=0.909 Recall=0.858 F1=0.883
# epoch 2302  loss=0.161949
#           test_loss=0.278171  Precision=0.905 Recall=0.860 F1=0.882
# epoch 2303  loss=0.171834
#           test_loss=0.297450  Precision=0.897 Recall=0.862 F1=0.879
# epoch 2304  loss=0.172060
#           test_loss=0.277262  Precision=0.898 Recall=0.855 F1=0.876
# epoch 2305  loss=0.167522
#           test_loss=0.268328  Precision=0.897 Recall=0.865 F1=0.881
# epoch 2306  loss=0.169171
#           test_loss=0.301063  Precision=0.918 Recall=0.836 F1=0.875
# epoch 2307  loss=0.173078
#           test_loss=0.274799  Precision=0.894 Recall=0.871 F1=0.882
# epoch 2308  loss=0.172941
#           test_loss=0.261205  Precision=0.890 Recall=0.892 F1=0.891
# epoch 2309  loss=0.167168
#           test_loss=0.259613  Precision=0.913 Recall=0.873 F1=0.893
# epoch 2310  loss=0.169416
#           test_loss=0.301675  Precision=0.886 Recall=0.855 F1=0.871
# epoch 2311  loss=0.162726
#           test_loss=0.254529  Precision=0.900 Recall=0.885 F1=0.893
# epoch 2312  loss=0.167075
#           test_loss=0.275387  Precision=0.893 Recall=0.863 F1=0.877
# epoch 2313  loss=0.167678
#           test_loss=0.275246  Precision=0.918 Recall=0.864 F1=0.890
# epoch 2314  loss=0.163632
#           test_loss=0.275915  Precision=0.876 Recall=0.857 F1=0.867
# epoch 2315  loss=0.165344
#           test_loss=0.265754  Precision=0.910 Recall=0.853 F1=0.881
# epoch 2316  loss=0.167465
#           test_loss=0.273916  Precision=0.915 Recall=0.852 F1=0.883
# epoch 2317  loss=0.177217
#           test_loss=0.275113  Precision=0.896 Recall=0.857 F1=0.876
# epoch 2318  loss=0.166293
#           test_loss=0.242612  Precision=0.914 Recall=0.897 F1=0.905
# epoch 2319  loss=0.163966
#           test_loss=0.258541  Precision=0.908 Recall=0.873 F1=0.890
# epoch 2320  loss=0.169061
#           test_loss=0.271510  Precision=0.911 Recall=0.839 F1=0.874
# epoch 2321  loss=0.174191
#           test_loss=0.254958  Precision=0.903 Recall=0.873 F1=0.888
# epoch 2322  loss=0.168284
#           test_loss=0.279287  Precision=0.900 Recall=0.855 F1=0.877
# epoch 2323  loss=0.171130
#           test_loss=0.285724  Precision=0.897 Recall=0.836 F1=0.865
# epoch 2324  loss=0.169127
#           test_loss=0.282805  Precision=0.887 Recall=0.829 F1=0.857
# epoch 2325  loss=0.167713
#           test_loss=0.289553  Precision=0.902 Recall=0.869 F1=0.885
# epoch 2326  loss=0.168226
#           test_loss=0.270896  Precision=0.922 Recall=0.885 F1=0.903
# epoch 2327  loss=0.169297
#           test_loss=0.244993  Precision=0.923 Recall=0.865 F1=0.893
# epoch 2328  loss=0.172307
#           test_loss=0.261653  Precision=0.915 Recall=0.874 F1=0.894
# epoch 2329  loss=0.172797
#           test_loss=0.300979  Precision=0.893 Recall=0.859 F1=0.875
# epoch 2330  loss=0.173525
#           test_loss=0.285466  Precision=0.873 Recall=0.876 F1=0.875
# epoch 2331  loss=0.173629
#           test_loss=0.262900  Precision=0.920 Recall=0.853 F1=0.885
# epoch 2332  loss=0.171163
#           test_loss=0.257362  Precision=0.906 Recall=0.875 F1=0.890
# epoch 2333  loss=0.169235
#           test_loss=0.258025  Precision=0.899 Recall=0.883 F1=0.891
# epoch 2334  loss=0.165875
#           test_loss=0.275832  Precision=0.909 Recall=0.850 F1=0.879
# epoch 2335  loss=0.166091
#           test_loss=0.258005  Precision=0.898 Recall=0.880 F1=0.889
# epoch 2336  loss=0.170991
#           test_loss=0.262976  Precision=0.921 Recall=0.859 F1=0.889
# epoch 2337  loss=0.165223
#           test_loss=0.285632  Precision=0.914 Recall=0.861 F1=0.887
# epoch 2338  loss=0.171957
#           test_loss=0.279704  Precision=0.892 Recall=0.855 F1=0.873
# epoch 2339  loss=0.168946
#           test_loss=0.273176  Precision=0.921 Recall=0.869 F1=0.894
# epoch 2340  loss=0.163772
#           test_loss=0.293164  Precision=0.929 Recall=0.859 F1=0.893
# epoch 2341  loss=0.170918
#           test_loss=0.275786  Precision=0.915 Recall=0.844 F1=0.878
# epoch 2342  loss=0.175032
#           test_loss=0.279403  Precision=0.897 Recall=0.861 F1=0.878
# epoch 2343  loss=0.168122
#           test_loss=0.264957  Precision=0.900 Recall=0.857 F1=0.878
#
# Stopped by user. Done.

# %%
# For testing inferrence

# Sample a new 8-bar pattern (T is now inferred from loaded data)
# h, v = sample_pattern(
#     model,
#     T=T,
#     n_iters=16,
#     device="cpu",
#     density_bias=0.0,      # + => busier, - => sparser, range of [-3, 3]
#     sigma_floor=0.08,      # higher => more velocity variation
#     resample_fraction=0.45,
#     temperature_hit=1.0,
# )

# print("hit:", h.numpy().astype(int).tolist())
# midi_vel = (v.numpy() * 127.0).round().astype(int).tolist()
# print("vel:", midi_vel)

# out_path = export_single_voice_steps_to_midi(
#     hit=h.numpy(),
#     vel=v.numpy(),
#     out_dir="./generated_midis",
#     cfg=cfg_out,
# )

# print("Saved MIDI:", out_path)

# %%
# Inspect a midi file

# import mido
# from collections import Counter

# def inspect_midi(path: str, max_print: int = 10):
#     mid = mido.MidiFile(path)
#     print("ticks_per_beat:", mid.ticks_per_beat)

#     pitch_counts = Counter()
#     chan_counts = Counter()
#     events = 0

#     for tr_i, track in enumerate(mid.tracks):
#         abs_tick = 0
#         for msg in track:
#             abs_tick += msg.time
#             if msg.type == "note_on" and msg.velocity > 0:
#                 events += 1
#                 chan = getattr(msg, "channel", None)
#                 pitch_counts[msg.note] += 1
#                 chan_counts[chan] += 1

#     print("note_on events:", events)
#     print("top pitches:", pitch_counts.most_common(max_print))
#     print("channels:", chan_counts.most_common())

# inspect_midi("MIDI/1hit.mid")
